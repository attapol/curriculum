# %% [markdown]
# # บทที่ 2 - ชุดข้อมูลมหัศจรรย์และถิ่นที่อยู่

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ai-builders/curriculum/blob/main/notebooks/02_fantastic_datasets.ipynb)

# %% [markdown]
# ในปัจจุบันชุดข้อมูลที่มีพร้อมทั้งปริมาณและคุณภาพเป็นส่วนสำคัญในการสร้าง ML models ในบทเรียนนี้เราจะเรียนรู้วิธีการหาข้อมูลมาเทรนโมเดลของเราทั้งจากชุดข้อมูล open data, web scraping, หรือสร้างขึ้นมาเองจากโมเดลและโค้ด open source ทั้งนี้การหาข้อมูลมาเทรนโมเดลจากแหล่งข้อมูลสาธารณะที่กล่าวมานั้นเราต้องให้ความสำคัญเรื่องลิขสิทธิ์และจริยธรรม (แม้แต่โมเดลเองก็สร้างข้อมูลที่ผิดลิขสิทธิ์-จริยธรรมได้; เรียนเพิ่มเติมในบทที่ 7)

# %% [markdown]
# ## ติดตั้ง Package ที่ต้องใช้งาน

# %%
#fastai
# !pip install -q fastbook==0.0.29

#ctgan
# !pip -q install ctgan
# !pip -q install sdv

#review generation
# !pip install -q transformers

#DuckDuckGo Search API
# !pip install -q duckduckgo_search==5.3.0b4

#selenium
# !pip install -q google-colab-selenium

#dspy
# !pip install -q dspy
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 13.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.0/259.0 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 18.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.4 MB/s eta 0:00:00
#   Building wheel for litellm (pyproject.toml) ... done

# %% [markdown]
# ## Data-centric AI เมื่อปริมาณ-คุณภาพข้อมูลสำคัญเท่ากับหรือมากกว่าคุณภาพโมเดล

# %% [markdown]
# ในปัจจุบันเรามีสถาปัตยกรรมประสิทธิภาพสูงมากมายให้เลือกใช้ทำ ML models (images - ResNet/EfficientNet, texts - BERT family, tabular data - gradient boosted trees) ปริมาณและคุณภาพของชุดข้อมูลจึงเริ่มมีความสำคัญมากยิ่งขึ้นในการทำให้ประสิทธิภาพของโมเดลของเราดีขึ้น
#
# แนวคิด Data-centric AI ถูกทำให้เป็นที่รู้จักโดย [Andrew Ng และ Landing AI](https://landing.ai/data-centric-ai/) กล่าวคือแทนที่เราจะพยามสร้างโมเดลที่มีประสิทธิภาพยิ่งขึ้น (และโดยส่วนใหญ่แล้วซับซ้อน ใหญ่ และใช้งานยากขึ้น)ให้เรามาใช้เวลาในการ 1) เพิ่มปริมาณข้อมูลและ 2) พัฒนาคุณภาพข้อมูลแทน
#
# ยกตัวอย่าง Data-centric AI ในการตัดคำภาษาไทยด้วยโมเดลโดย [@kornwtp](https://medium.com/@kornwtp/) ในบทความ [Data-Centric ML for Thai Word Segmentation](https://medium.com/@kornwtp/data-centric-for-thai-word-segmentation-e31a79db650d) พวกเขาทำการทดลองตัดคำภาษาไทยด้วยชุดข้อมูล [VISTEC-TP-TH-2021](https://github.com/mrpeerat/OSKut/tree/main/VISTEC-TP-TH-2021) (ประมาณ 5 หมื่นประโยค) ด้วยโมเดล [deepcut](https://github.com/rkcosmos/deepcut) อย่างที่เห็นในตารางรายงานผล การเพิ่มขนาดโมเดลถึง 1 เท่าตัวมีผลให้ความแม่นยำเพิ่มขึ้นเพียงแค่ 1.37% กลับกันการเพิ่มข้อมูลเพียงแค่ 1,500 ตัวอย่างทำให้ความแม่นยำเพิ่มขึ้นถึง 4.90% ยิ่งถ้าข้อมูลที่เพิ่มถูกทำความสะอาดแล้วจะทำให้เพิ่มขึ้นถึง 7.48% (แน่นอนว่าถ้ายิ่งโมเดลใหญ่และข้อมูลเยอะก็ยิ่งดี)
#
# <img src=https://miro.medium.com/max/1400/0*J2vA5iRnIMfuDDAc width="500px">

# %% [markdown]
# ## ชุดข้อมูลสาธารณะ - Open Data and Open Source

# %% [markdown]
# ชุดข้อมูล open data และโค้ด open source ถือเป็นสาธารณูปโภคขั้นพื้นฐานของการทำ ML และโชคดีที่น่าจะเป็นสาธารณูปโภคขั้นพื้นฐานไม่กี่อย่างที่เราในฐานะบุคคลสามารถช่วยกันสร้างได้ด้วยการนำไปใช้-เผยแพร่ชุดข้อมูลและโค้ด
#
# โดยทั่วไปแล้ว ชุดข้อมูลจะถูกเผยแพร่ภายใต้ [Creative Commons Licenses](https://creativecommons.org/) ที่นิยมดังต่อไปนี้
#
# * `CC` - Creative Commons
# * `BY` (Attribution) - ใช้ทำซ้ำ แจกจ่าย ดัดแปลงได้ แต่ต้องอ้างอิงเจ้าของผลงาน
# * `SA` (ShareAlike) - ใช้ทำซ้ำ แจกจ่าย ดัดแปลงได้ แต่ต้องคง License เดิมไว้
# * `NC` (NonCommercial) - ใช้ทำซ้ำ แจกจ่าย ดัดแปลงได้ แต่ห้ามใช้เพื่อการค้า
# * `ND` (NoDerivatives) - ใช้ทำซ้ำ แจกจ่ายได้ แต่ห้ามดัดแปลง
#
# เราแนะนำให้คุณแบ่งปันผลงานเป็น `CC-BY-SA` เพื่อให้ชุมชนนักพัฒนาสามารถนำไปต่อยอดได้ เหมือนเช่นที่เรานำงานของชุมชนมาต่อยอด
#
# คุณสามารถเลือก License ที่คุณต้องการได้[ที่นี่](https://creativecommons.org/choose/)

# %% [markdown]
# ### แหล่งค้นหาชุดข้อมูล

# %% [markdown]
# ต่อไปนี้คือแหล่งข้อมูลหลักๆที่คุณสามารถพบเจอชุดข้อมูล open data

# %% [markdown]
# แหล่งค้นหาชุดข้อมูลทั่วไป
# * [Kaggle](https://www.kaggle.com/datasets)
# * [Google Dataset Search](https://datasetsearch.research.google.com/)
# * [Papers with Code](https://paperswithcode.com/datasets)
# * [Tensorflow Datasets](https://www.tensorflow.org/datasets)
#
# แหล่งค้นหาชุดข้อมูล Images
# * [Open Images Dataset](https://storage.googleapis.com/openimages/web/index.html)
# * [torchvision.datasets](https://pytorch.org/vision/stable/datasets.html)
#
# แหล่งค้นหาชุดข้อมูล NLP และ Speech
# * [Hugging Face Datasets](https://huggingface.co/datasets)
# * [torchtext.datasets](https://pytorch.org/text/stable/datasets.html)
# * [torchaudio.datasets](https://pytorch.org/audio/stable/datasets.html)
# * [NLP for Thai](https://nlpforthai.com/)
#
#
# แหล่งค้นหาชุดข้อมูล Tabular Data
# * [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php)

# %% [markdown]
# ### ชื่อ Task ไว้ใช้ค้นหาชุดข้อมูล

# %% [markdown]
# อีกแนวทางการค้นหาข้อมูลคือค้นหา "[ชื่อ task] datasets" ใน search engine

# %% [markdown]
# Images
# * Image classification; จำแนกรูปภาพ
# * Object detection; จับวัตถุในรูปภาพ
# * Image segmentation; จำแนก pixel ในรูปภาพ
# * Image information retrieval (search); ค้นหารูปภาพด้วยรูปภาพ
# * Image captioning; ใส่คำบรรยายให้รูปภาพ
# * Visual question answering; ตอบคำถามจากรูปภาพ
# * Image generation; สร้างรูปภาพ
# * Image reconstruction; ซ่อมแซมรูปภาพ (รูปเก่า, เซนเซอร์ ฯลฯ)
# * Style transfer; เปลี่ยนสไตล์ของรูปภาพ
#
# NLP
# * Sequence classification; จำแนกข้อความ
# * Token classification; จำแนกหน่วยคำในข้อความ
# * Extractive question answering; ตอบคำถามจากบทความ
# * Machine translation; แปลภาษา
# * Summarization; ย่อความ
# * Paraphrasing; ถอดความ
# * Optical character recognition; เปลี่ยนตัวอักษรในภาพเป็นข้อความ
# * Text information retrieval (search); ค้นหาข้อความด้วยข้อความ
# * Text generation; สร้างข้อความ
# * Dialogue; สร้างบทสนทนาตอบโต้
#
# Speech
# * Speech classification; จำแนกเสียง
# * Automatic speech recognition; ถอดเสียงเป็นข้อความ
# * Speech synthesis; สร้างเสียง (จากข้อความ)
# * Speaker recognition; จำแนกผู้พูด
#
# Tabular Data
# * Multi-class classification; จำแนกตัวอย่าง (1 ตัวอย่าง = 1 ประเภท)
# * Multi-label classification; จำแนกตัวอย่าง (1 ตัวอย่าง = มากกว่า 1 ประเภท)
# * Regression; ทำนายจำนวนจริง
# * Time series forecasting; ทำนายตัวเลขในเชิงเวลา
# * Recommendation; แนะนำสิ่งของ

# %% [markdown]
# ## หารูปภาพจาก DuckDuckGo Image Search API

# %% [markdown]
# เทคนิคแนะนำโดย [fastai v4 part1 lesson 2](https://github.com/fastai/fastbook/blob/master/02_production.ipynb) ผู้ที่สนใจสามารถไปติดตามบทเรียนต้นทางได้ที่ [course.fast.ai](https://course.fast.ai/) สามารถใช้ search engine อื่นๆ เช่น Google, Bing เป็นต้น เราเลือกใช้ DuckDuckGo เนื่องจากความสะดวกที่สามารถส่งคำขอค้นหารูปภาพได้โดยไม่ต้องใช้ API key

# %%
from fastbook import *
from fastai.vision.widgets import *
from tqdm.auto import tqdm
from duckduckgo_search import DDGS

#download from duckduckgo
def search_images_ddg(key, max_n=200):
     """Search for 'key' with DuckDuckGo and return a unique urls of 'max_n' images
        (Adopted from https://github.com/deepanprabhu/duckduckgo-images-api)
     """
     url        = 'https://duckduckgo.com/'
     params     = {'q':key}
     res        = requests.post(url,data=params)
     searchObj  = re.search(r'vqd=([\d-]+)\&',res.text)
     if not searchObj: print('Token Parsing Failed !'); return
     requestUrl = url + 'i.js'
     headers    = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:71.0) Gecko/20100101 Firefox/71.0'}
     params     = (('l','us-en'),('o','json'),('q',key),('vqd',searchObj.group(1)),('f',',,,'),('p','1'),('v7exp','a'))
     urls       = []
     while True:
         try:
             res  = requests.get(requestUrl,headers=headers,params=params)
             data = json.loads(res.text)
             for obj in data['results']:
                 urls.append(obj['image'])
                 max_n = max_n - 1
                 if max_n < 1: return L(set(urls))     # dedupe
             if 'next' not in data: return L(set(urls))
             requestUrl = url + data['next']
         except:
             pass

def search_images_ddg_v2(key,max_n=200):
    """Search for 'key' with DuckDuckGo and return a unique urls of 'max_n' images
        Note: Instead of using our own implementation, we using library instead!
    """
    responses = DDGS().images(
                          keywords=key,
                          region="wt-wt",
                          safesearch="off",
                          size=None,
                          color=None,
                          type_image=None,
                          layout=None,
                          license_image=None,
                          max_results=max_n,
                      )
    urls = [ r['image'] for r in responses ]
    return urls

# %%
#save ไว้ที่ไหน
path = Path('images')
#เอารูปอะไรบ้าง (labels)
labels = ['chocolate chip cookies','raisin cookies']
#เอา label ละกี่รูป
MAX_N = 100

if not path.exists():
    path.mkdir()
for l in tqdm(labels):
    dest = (path/l)
    dest.mkdir(exist_ok=True)
    results = search_images_ddg_v2(l, max_n=MAX_N)
    download_images(dest, urls=results)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
#เช็คว่าได้รูปอะไรบ้าง
fns = get_image_files(path)
fns
# Out:
# (#134) [Path('images/chocolate chip cookies/89fea001-cac4-493e-a197-7485a2d9a9c2.jpg'),Path('images/chocolate chip cookies/69624138-3cf5-4ac4-a119-0b12edd5bc74.jpg'),Path('images/chocolate chip cookies/4b56aac3-61e7-48dc-a271-0637c24820de.jpg'),Path('images/chocolate chip cookies/0e344a25-8890-4896-93ac-6a7f2744e1de.jpg'),Path('images/chocolate chip cookies/cefab13c-26f0-4140-9613-94bf1bff7435.jpg'),Path('images/chocolate chip cookies/95873b5a-0bfb-497f-adee-7bfef6a67925.jpg'),Path('images/chocolate chip cookies/1fa270da-e416-40e7-8695-57763b4a53ed.jpg'),Path('images/chocolate chip cookies/eb94674e-513b-4707-8d80-6a374be180e8.jpg'),Path('images/chocolate chip cookies/53278371-dc70-4e2e-b516-674aac0998a5.jpg'),Path('images/chocolate chip cookies/2df094d2-98d9-4a2d-aa29-2f75aaf1ae24.jpg'),Path('images/chocolate chip cookies/d6464b7a-d40b-455a-b09a-6e0752b25877.jpg'),Path('images/chocolate chip cookies/5ebb8a0b-bcb8-4f6f-bda6-f83993d8cb11.jpg'),Path('images/chocolate chip cookies/216a4bb0-ccd2-460c-b725-6ade42b8d05b.jpg'),Path('images/chocolate chip cookies/46a39119-09ee-4f22-a610-1a43bcf5ec38.jpg'),Path('images/chocolate chip cookies/f466760f-a64f-47e7-80dd-89700eed5c1d.jpg'),Path('images/chocolate chip cookies/66790357-bbe3-4dfc-977d-01c1c1c2221b.jpg'),Path('images/chocolate chip cookies/1d1bf290-7bfa-4c58-97d0-dbb01682761a.jpg'),Path('images/chocolate chip cookies/5052446a-e9f2-4824-b7cd-599476439bd0.jpg'),Path('images/chocolate chip cookies/c637b3e7-d043-4057-9472-b1fb74d361e7.jpg'),Path('images/chocolate chip cookies/3a3a6574-dea7-42bf-b84f-0a9c912baa6d.jpg')...]

# %%
#ดูว่าหารูปไหนไม่เจอบ้าง
failed = verify_images(fns)
failed
# Out:
# (#0) []

# %%
#นำรูปที่หาไม่เจอออก
failed.map(Path.unlink)
# Out:
# (#0) []

# %% [markdown]
# ## Web Scraping ดึงข้อมูลจากเว็บไซต์สาธารณะ

# %% [markdown]
# Web Scraping คือการเขียนโปรแกรมดึงข้อมูลจากเว็บไซต์สาธารณะ ข้อควรระวังคือแม้โดยความเป็นจริงแล้วข้อมูลเหล่านั้นจะถูกเปิดเผยให้ใครเข้าไปดูก็ได้ แต่ไม่ได้หมายความว่าเจ้าของเว็บไซต์จะอยากให้เราดึงข้อมูลจำนวนมากจากเว็บไซต์ของพวกเขา ไม่ว่าจะด้วยเหตุผลด้านลิขสิทธิ์การใช้งานหรือการเพิ่มภาระให้เซิร์ฟเวอร์ของเว็บไซต์นั้นๆ ยกตัวอย่างเช่น Facebook หรือ Twitter ที่ข้อตกลงการใช้งานของพวกเขาไม่อนุญาตให้เราดึงข้อมูลด้วย Web Scraping แต่อนุญาตให้ดึงข้อมูลผ่าน API อย่างเป็นทางการแทน
#
# หากไม่แน่ใจในนโยบายการใช้งาน ทางที่ดีควรติดต่อขออนุญาตจากเจ้าของเว็บไซต์ก่อน นี่คือตัวอย่างที่ทางทีมงานติดต่อไปยัง [soccersuck.com](https://www.soccersuck.com) เพื่อขออนุญาตนำมาใช้สอน
#
# > ทีมงาน AI Builders: สวัสดีครับ ผมทำโครงการสอนเด็กมัธยมทำ AI ชื่อ AI Builders (https://www.facebook.com/aibuildersx) อยู่ครับ พอดีครั้งนี้เราจะจัดสอนช่วงหลังสงกรานต์ และมีหัวข้อหนึ่งคือ web scraping หรือการเขียนโปรแกรมดึงเนื้อหาจากเว็บไซต์ อยากขออนุญาตใช้ https://www.soccersuck.com/boards/oldnews เป็นตัวอย่างในการฝึกสอนครับ โดนสอนให้น้องๆเขียนโปรแกรมดึงพาดหัวข่าว, url ข่าว, และเนื้อข่าวเฉพาะกระทู้ที่อยู่ใน old news 3 หน้าเท่านั้น โปรแกรมทั้งหมดใช้เพื่อสาธิตในการศึกษาครับ นักเรียนมีจำนวน 50 คน คิดว่าไม่มีปัญหา traffic แม้จะกดรันโค้ดพร้อมกันทุกคนครับ
#
# > Soccersuck: ได้ครับไม่มีปัญหา

# %% [markdown]
# ### Static Web

# %% [markdown]
# สมมุติว่าเราอยากทำโมเดล "เขียนพาดหัวข่าวฟุตบอลจากเนื้อข่าวในเว็บ [soccersuck.com](https://www.soccersuck.com/boards/oldnews)"

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### ดึง HTML มาเปลี่ยนเป็น Soup

# %%
#package สำหรับจัดการ html เรียกว่า BeautifulSoup
def get_soup(url):
    with requests.get(url) as r:
        soup = BeautifulSoup(r.text, features='html.parser')
    return soup

# %%
#ดึงข้อมูล html จากเว็บไซต์มาเปลี่ยนเป็น soup
url = f'https://www.soccersuck.com/boards/oldnews/1/'
soup = get_soup(url)
soup
# Out:
# <!DOCTYPE HTML>
#
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/> <title>
# 		#### ได้รู้ความจริง ได้ยิ่งกว่าฟุตบอล อ่าน soccersuck.com####	</title>
# <link href="/img/web/ss_logo_f_16.ico" rel="shortcut icon"/>
# <meta content="app-id=1042191005" name="apple-itunes-app"/>
# <meta content="app-id=com.soccersuck.devtab.com.soccersuck" name="google-play-app"/>
# <link href="https://www.soccersuck.com/css/jquery.smartbanner.css" media="screen" rel="stylesheet" type="text/css"/>
# <meta content="ข่าวฟุตบอล ข่าวบอล นักฟุตบอล ผลการแข่งขัน ข่าวลือ ข่าวการย้ายทีม บอลอังกฤษ บอลเยอรมัน บอลอิตาลี บอลสเปน ฟุตบอล บอบทีมชาติ บอลไทย บอลทีมชติไทย เว็บบอร์ด วาไรตี้ ภาพเซ็กซี่ 18+ โปรแกรมการแข่งขัน โปรแกรมถ่ายทอดสด" name="description">
# <meta content="ข่าวฟุตบอล,ข่าวบอล,ผลการแข่งขัน,นักฟุตบอล,บอลอังกฤษ,บอลเยอรมัน,บอลอิตาลี,บอลสเปน,ฟุตบอล,ข่าวการย้ายทีม,ภาพเซ็กซี่,18+" name="keyword">
# <meta content="NTViMzdjNWMyNzBlNWQ4NGM3OTNlNDg2ZDc5OGMwMWQ=" name="thstats-verify"/>
# <meta content="SoccerSuck" property="og:title"/>
# <meta content="https://www.soccersuck.com/img/web/ss_main_h_logo_ss.png" property="og:image"/>
# <meta content="ได้รู้ความจริงยิ่งกว่าฟุตบอล" property="og:description"/>
# <meta content="https://www.soccersuck.com/" property="og:url"/>
# <link href="https://www.soccersuck.com/img/web/ss_main_h_logo_ss.png" rel="image_src">
# <link href="https://fonts.googleapis.com/css?family=Prompt:400,400i,500,500i" rel="stylesheet"/><link href="/css/cake.generic.css" rel="stylesheet" type="text/css"><link href="/css/header.css" rel="stylesheet" type="text/css"/><link href="/css/home.css?v3.33" rel="stylesheet" type="text/css"/><script src="/js/jquery.js?v=12.2" type="text/javascript"></script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-65318217-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-65318217-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-65318217-1');
# </script>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-XZXQFTJH0B"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-XZXQFTJH0B');
# </script>
# <!-- DFP -->
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/16403602/soccersuck_web_xc', [420, 300], 'div-gpt-ad-1488813165691-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <!-- TikTok -->
# <script>
#   !function (w, d, t) {
#     w.TiktokAnalyticsObject=t;var ttq=w[t]=w[t]||[];ttq.methods=["page","track","identify","instances","debug","on","off","once","ready","alias","group","enableCookie","disableCookie"],ttq.setAndDefer=function(t,e){t[e]=function(){t.push([e].concat(Array.prototype.slice.call(arguments,0)))}};for(var i=0;i<ttq.methods.length;i++)ttq.setAndDefer(ttq,ttq.methods[i]);ttq.instance=function(t){for(var e=ttq._i[t]||[],n=0;n<ttq.methods.length;n++)ttq.setAndDefer(e,ttq.methods[n]);return e},ttq.load=function(e,n){var i="https://analytics.tiktok.com/i18n/pixel/events.js";ttq._i=ttq._i||{},ttq._i[e]=[],ttq._i[e]._u=i,ttq._t=ttq._t||{},ttq._t[e]=+new Date,ttq._o=ttq._o||{},ttq._o[e]=n||{};var o=document.createElement("script");o.type="text/javascript",o.async=!0,o.src=i+"?sdkid="+e+"&lib="+t;var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(o,a)};
#     ttq.load('CDTGQVBC77U2BHNF7J70');
#     ttq.page();
#   }(window, document, 'ttq');
# </script>
# <!-- Smartlook -->
# <script type="text/javascript">
#   window.smartlook||(function(d) {
#     var o=smartlook=function(){ o.api.push(arguments)},h=d.getElementsByTagName('head')[0];
#     var c=d.createElement('script');o.api=new Array();c.async=true;c.type='text/javascript';
#     c.charset='utf-8';c.src='https://web-sdk.smartlook.com/recorder.js';h.appendChild(c);
#     })(document);
#     smartlook('init', '609a2fb2d12c5d70c793a617fbfd9c5889024fb1', { region: 'eu' });
# </script>
# <!-- OneSignal -->
# <script async="async" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#     var OneSignal = window.OneSignal || [];
#     OneSignal.push(["init", {
#       appId: "0a2d7f58-8864-4b03-a081-194606aeee94",
#       autoRegister: true, /* Set to true to automatically prompt visitors */
#       subdomainName: 'soccersuck',
#       /*
#       subdomainName: Use the value you entered in step 1.4: http://imgur.com/a/f6hqN
#       */
#       httpPermissionRequest: {
#         enable: true
#       },
#       notifyButton: {
#           enable: false /* Set to false to hide */
#       },
#       safari_web_id: 'web.onesignal.auto.4ed01e00-f557-41b7-a4bd-c51172d553fd',
#       welcomeNotification: {
#         disable: true
#     }
#     }]);
#   </script>
# <!-- update 9 Feb 59 -->
# <script type="text/javascript">
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/16403602/ss_cover', [1000, 500], 'div-gpt-ad-1455029775949-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <!-- update 9 Feb 59 -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MW9THLS');</script>
# <!-- End Google Tag Manager -->
# <script async="" data-ad-client="ca-pub-6459522510239433" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# </link></link></meta></meta></head>
# <body>
# <div id="fb-root"></div>
# <script src="https://connect.facebook.net/en_US/all.js" type="text/javascript"></script> <script src="/js/fb_init.js" type="text/javascript"></script> <div id="header">
# <div class="header_layout">
# <a href="https://www.soccersuck.com/" style="color:#000;"><div class="logo"></div></a>
# <div class="header_offline">
# <div style="float: right;">
# <a href="https://www.soccersuck.com/users/register/" style="text-decoration: none;">
# <div class="header_register">Register</div>
# </a>
# </div>
# <div style="float: right;">
# <div class="header_login">Login</div>
# </div>
# <div style="float:right;">
# <div style="float: left;margin: 3px 10px 0px 0px; ">
# <div class="header_label">Username</div>
# <div class="header_input"><input id="header_email" type="text"/></div>
# </div>
# <div style="float: left;margin: 3px 10px 0px 0px;">
# <div class="header_label">Password</div>
# <div class="header_input"><input id="header_pass" type="password"/></div>
# </div>
# <div class="clear"></div>
# <div style="float: left;margin: 0px 10px 0px 0px;">
# <div class="header_label"><input checked="" id="header_ckemail" style="" type="checkbox"/> จำรหัสผ่าน</div>
# </div>
# <div style="float: left;margin: 0px 0px 0px 11px;">
# <a href="https://www.soccersuck.com/users/forgotpassword" style="color:#000;text-decoration: none;">
# <div class="header_label">ลืมรหัสผ่าน?</div>
# </a>
# </div>
# <div class="clear"></div>
# </div>
# <div style="float: right;">
# <div style="margin:  9px 10px 0px 0px;float: left;"><a href="https://www.soccersuck.com/boards/topic/875245" style="text-decoration: none;color: #FFF;" target="_blank"><div class="bthowto"></div></a></div>
# <div style="margin: 15px 5px 0px 5px;float: left;"><a href="https://www.soccersuck.com/users/jail" style="text-decoration: none;color: #FFF;" target="_blank"><div class="btprisoner"></div></a></div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="loaddingHeader" style="display: none;background: #FFF;position: fixed;padding: 20px;top: 50%;left: 50%;margin:-45px 0px 0px -45px;box-shadow: 4px 4px 4px #888;"><img src="/img/web/loading_50.gif"/></div>
# <script src="/js/login.js" type="text/javascript"></script> </div>
# <div id="container">
# <div class="content_left">
# <div style="margin: 0px 0px 2px 10px;">
# </div>
# <ul class="menu_left">
# <a href="https://www.soccersuck.com/shop" style="color: #FFF;text-decoration: none;" target="_blank">
# <li>
# <img alt="" src="/img/web/top_item.png?1" style="width: 90px;margin: 4px 21px;"/>
# </li>
# </a>
# <a href="https://www.soccersuck.com/" style="color: #FFF;text-decoration: none;" target="_blank">
# <li>
# <img alt="" src="/img/web/ss_main_icon_menu_29.png" style="width:25px;margin: 8px -2px -7px 2px;"> <span>หน้าแรก</span>
# </img></li>
# </a>
# <!-- <a target="_blank" href="https://www.soccersuck.in.th" style="color: #FFF;text-decoration: none;">
#                                 <li>
#                                     <img src="/img/new-logo-ss.png" style="width:22px;margin: 8px 0px -8px 2px;" alt="">
#                                     <span>ใช้งานเวอร์ชั่นใหม่!</span>
#                                 </li>
#                             </a> -->
# <!-- <a target="_blank" href="https://wc2022.soccersuck.com" style="color: #FFF;text-decoration: none;">
#                                 <li class="wc-2022-menu">
#                                     <img src="/img/ss-wc2022-logo.png" style="width:22px;margin: 8px 0px -8px 2px;" alt="">
#                                     <span>ข่าวฟุตบอลโลก!</span>
#                                 </li>
#                             </a> -->
# <style>
#                                 .menu_left .wc-2022-menu {
#                                     background: #ab1e1e;
#                                     background: linear-gradient(-30deg, darkred, #ab1e1e, darkred);
#                                 }
#                                 .menu_left .wc-2022-menu:hover {
#                                     background: linear-gradient(-30deg, #d21d1d, #ab1e1e, #d21d1d);
#                                 }
#                             </style>
# <!--  <a target="_blank" href="http://www.goal168tv.com/" style="color: #FFF;text-decoration: none;">
#                             <li>
#                                 <img src="/images/Aug-05-2560%2020-20-28.gif" style="width:139px;" alt="" />
#                             </li>
#                              </a> -->
# <a href="https://www.soccersuck.com/boards/oldnews/" style="color: #FFF;text-decoration: none;" target="_blank">
# <li>
# <img alt="" src="/img/web/ss_main_icon_menu_33.png" style="width:25px;margin: 9px 0px -4px 1px;"/> <span>ข่าวเก่า</span>
# </li>
# </a>
# <a href="https://www.soccersuck.com/boards/matchreport/" style="color: #FFF;text-decoration: none;" target="_blank">
# <li>
# <img alt="" src="/img/web/ss_main_icon_menu_55.png" style="width:25px;margin: 6px -4px -7px 4px;"/> <span>ผลบอลย้อนหลัง</span>
# </li>
# </a>
# <!--     <a target="_blank" href="http://www.polballss.com/" style="color: #FFF;text-decoration: none;">
#                             <li>
#
#                                 <img src="/img/web/ss_main_icon_menu_38.png" style="width:25px;margin: 7px -4px -5px 1px;" alt="" />                                <span>ทีเด็ด เบนฟรีคิก</span>
#
#                             </li>
#                             </a>-->
# <!--<a target="_blank" href="http://www.guideball.com/" style="color: #FFF;text-decoration: none;">
#                             <li>
#
#                                 <img src="/img/web/ss_main_icon_menu_41.png" style="width:25px;margin: 9px -4px -6px 1px;" alt="" />                                <span>รายงานสดผลบอล</span>
#
#                             </li>
#                             </a>-->
# <a href="https://www.soccersuck.com/boards/topic/1938391" style="color: #FFF;text-decoration: none;" target="_blank">
# <li>
# <img alt="" src="/img/web/ss_main_icon_menu_43.png" style="width:25px;margin: 12px -4px -3px 2px;"/> <span style="font-size: 11px;">โปรแกรมถ่ายทอดสด</span>
# </li>
# </a>
# <a href="https://www.soccersuck.com/boards/topic/1938391" style="color: #FFF;text-decoration: none;" target="_blank">
# <li>
# <img alt="" src="/img/web/ss_main_icon_menu_45.png" style="width:25px;margin: 10px -4px -4px 2px;"/> <span style="font-size: 11px;">โปรแกรมบอลล่วงหน้า</span>
# </li>
# </a>
# <a href="https://www.soccersuck.com/boards/topic/994224" style="color: #FFF;text-decoration: none;" target="_blank">
# <li>
# <img alt="" src="/img/web/ss_main_icon_menu_49.png" style="width:25px;margin: 8px -3px -6px 2px;"/> <span>สรุปผลย้อนหลัง</span>
# </li>
# </a>
# <a href="https://www.soccersuck.com/menu/column" style="color: #FFF;text-decoration: none;" target="_blank">
# <li>
# <img alt="" src="/img/web/ss_main_icon_menu_55.png" style="width:25px;margin: 6px -4px -7px 5px;"/> <span>คอลัมน์+สกู๊ป</span>
# </li>
# </a>
# <a href="https://www.soccersuck.com/boards" style="color: #FFF;text-decoration: none;" target="_blank">
# <li>
# <img alt="" src="/img/web/ss_main_icon_menu_66.png" style="margin: 7px -1px -7px 5px;"/> <span>เว็บบอร์ด</span>
# </li>
# </a>
# <a href="https://www.soccersuck.com/menu/history" style="color: #FFF;text-decoration: none;" target="_blank">
# <li>
# <img alt="" src="/img/web/ss_main_icon_menu_68.png" style="width:25px;margin: 4px -1px -11px 5px;"/> <span>ประวัติ soccersuck</span>
# </li>
# </a>
# <!-- <a target="_blank" href="https://www.soccersuck.com/boards/topic/0" style="color: #FFF;text-decoration: none;">
#                             <li>
#                                 <img src="/img/web/ss_main_icon_menu_71.png" style="width:25px;margin: 9px -1px -7px 5px;" alt="" />                                <span>พาร์ทเนอร์</span>
#                             </li>
#                             </a>-->
# <a href="https://www.soccersuck.com/users/contact" style="color: #FFF;text-decoration: none;" target="_blank">
# <li>
# <img alt="" src="/img/web/ss_main_icon_menu_w.png" style="width:25px;margin: 9px 0px -4px 5px;"/> <span>ติดต่อโฆษณา</span>
# </li>
# </a>
# </ul>
# <script type="text/javascript">
#     $('.menu_left li').click(function(){
#
#         $('.menu_left li').removeClass('menu_left_selected');
#         $(this).addClass('menu_left_selected');
#         var inxmenu = $(this).index();
#         $('.sub_menu_left_pate').hide();
#         if(!$('.menu_left li:eq('+(inxmenu+1)+')').is(':visible')){
#             $('.menu_left li:eq('+(inxmenu+1)+')').show();
#         }
#     });
# </script>
# </div>
# <div class="content_main">
# <div class="adv_A">
# <div style="margin:2px 0px 0px 2px;">
# <!-- Composite Start -->
# <div id="M664411ScriptRootC1256745"></div>
# <script async="" src="https://jsc.mgid.com/s/o/soccersuck.com.1256745.js"></script>
# <!-- Composite End -->
# </div>
# </div>
# <div class="headline_head">
#                 ได้รู้ความจริงยิ่งกว่าฟุตบอล อ่านซ๊อกเกอร์ซัค
#             </div>
# <div style="border-top: 3px solid #f36523;width: 727px;margin: 0px 0px 0px 2px;"></div>
# <div class="headline" style="padding:1px 0px;">
# <div class="oldnew_p_thead">
# <img alt="" src="/img/web/ss_latest_new_icon_ca.png" style="margin:5px 5px -6px 5px;"/>08/04/25                    </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ita.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557166" target="_blank">
#                     มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/thailand.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557165" target="_blank">
#                     ไม่อยากกินบ๊วย! ‘ณัฐกิตติ์’ ยันสู้เต็มที่เพื่อเก็บสามแต้มส่ง...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ger.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557162" target="_blank">
#                     เร่เข้ามา! 'กิตเตนส์' แจ้งขอย้ายออกเสือเหลือง                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557156" target="_blank">
#                     แน่จริงนัดมา! สโคลส์เผยเคยโดน 'แข้งผีท้า' ไม่พอใจโ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557153" target="_blank">
#                     หารายได้! 'ผี' ทัวร์มาเล,ฮ่องกงหลังจบซีซั่น 3 วัน                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/ucl.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557139" target="_blank">
#                     ซูเปอร์คอมพ์ยก 'บาร์ซ่าเต็ง' เจ้ายุโรป ปืนเต็ง 3 เ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/thailand.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557131" target="_blank">
#                     จบรองแชมป์! ฟุตบอลหญิงไทย ต้านไม่ไหวพ่ายเจ้าภาพ จีน 1-5 ศึก ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557129" target="_blank">
#                     รอดประจำ! แฮ็คเกตต์สงสัย 'VVD' ตีสนิทเปาเลี่ยงใบแด...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/esp.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557120" target="_blank">
#                     วินิพอก่อน! อันเช่แต่งตั้ง 'บัปเป้' ตัวยิงจุดโทษ                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/ita.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557048" target="_blank">
#                     อิบราวาง 'ตาเร่' เต็งหนึ่ง ผอ.กีฬามิลาน                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557046" target="_blank">
#                     เป็นรอง 'หัวขิง'! ริโอเลือก 3 ตำนานมิดฟิลด์ไร้ KDB                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/esp.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557042" target="_blank">
#                     10 ประเด็นที่น่าสนใจในสัปดาห์ที่ 30 ของ ลาลีกา                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557041" target="_blank">
#                     แพงไปไหม?...'โคนาเต้' เรียกหงส์ 200k/w ต่อสัญญาใหม...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/esp.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557040" target="_blank">
#                     'จู๊ด' เสี่ยงโดนแบน 3 นัดเตะจอ VAR                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ita.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557037" target="_blank">
#                     ยังไม่มีคุย! เผยเจ้าของหมาป่าแค่เชิญ ETH ชมเกม                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557032" target="_blank">
#                     'ฮาว' ปลื้มสาลิกากลมเกลียวกว่าที่เคย                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557029" target="_blank">
#                     คาร์ร่าเชื่อจิ้งจอกเด้ง 'เฮียรุด' ทันทีที่ตกชั้น                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/ucl.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557025" target="_blank">
#                     'ซาก้า' ตั้งเป้าพาปืนผ่านรอบ 8 ทีม UCL                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ucl.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557020" target="_blank">
#                     ชมก่อนเชือด?! อันเช่หยอด 'พี่ต้า' พาปืนขึ้นหิ้งท็อ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/esp.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557016" target="_blank">
#                     อดีตนายด่านบาร์ซ่าย้อนความรอยร้าว 'เมสซี่ - น้าเก้'...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/fifa.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557015" target="_blank">
#                     RIP... 'โบลาโน' อดีตแข้งปาร์ม่าเสียชีวิตวัย 47 ปี                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557009" target="_blank">
#                     ผีรอดไป! FA รับทราบเคส 'ด่าแม่โฟเด้น' แจงไม่ได้ผิด...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557008" target="_blank">
#                     แฟนรุ่นปู่โวย! ผีขอคืนที่นั่งตั๋วปีไปจัดโซนแพง                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/fra.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556995" target="_blank">
#                     เด แซร์บี้เชื่อ 'ไม้เขียว' ดีพอเป็นตำนาน OM                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556990" target="_blank">
#                     เอฟเอเลื่อนพิจารณาคดี 'ปาเกต้า'                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556985" target="_blank">
#                     'อันโตนิโอ' เยี่ยมทีมแพทย์ยกเป็นฮีโร่ตัวจริง                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ucl.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556983" target="_blank">
#                     ปืนไร้ 'ราฮีม' รับมือราชันที่ได้ 'คูร์กตัวส์&amp;...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556979" target="_blank">
#                     ครบเครื่อง! 'ถีบจักร' ไม่แปลกใจ 'ดีแลป' ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556970" target="_blank">
#                     'คาร์ร่า+ถีบจักร' หวังนิวฯได้ลุย UCL - เห็นพ้องสิง...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/ucl.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556966" target="_blank">
#                     แคมป์เบลล์เตือนปืนจับตาย 'วินี่-จู๊ด' ถ้าอยากชนะรา...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ucl.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556959" target="_blank">
#                     'คูร์กตัวส์' รับราชันต้องระวังเซ็ตพีซปืน                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/esp.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556957" target="_blank">
#                     'ฟาติ' รับสภาพเบียดตำแหน่งยากเตรียมชิ่งหนีบาร์ซ่า                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556953" target="_blank">
#                     ให้เพื่อนได้พัก! 'โอนาน่า' โนสนแฟนบ่นออกบอลช้า                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556951" target="_blank">
#                     ริโอไม่ติดผีปล่อย 'การ์นาโช่' สลับขั้วดึง 'โอ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/usa.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556949" target="_blank">
#                     เผยไมอามีได้สิทธิ์คว้าตัว KDB ลุยลีกมะกัน                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/esp.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556946" target="_blank">
#                     บาร์ซ่าชกกลับ! สับ 'ลาลีกา' เอาข้อมูลการเงินมาเผยแ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556944" target="_blank">
#                     'คาร์ร่า' ชี้แผนคู่เซ็นเตอร์เท้าขวาปัจจัยหงส์พ่ายเ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556943" target="_blank">
#                     ปูดผีติดต่อเอเยนต์หวังเคลม 'คุนญ่า' ร้อนนี้                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ucl.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556941" target="_blank">
#                     'อันเช่' ยันจัดชุดดีสุดฉะปืนแม้หลายคนเสี่ยงโดนแบน                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/usa.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556934" target="_blank">
#                     อินเตอร์ ไมอามี่ สนดึง KDB ผนึกกำลังเมสซี่                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ucl.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556908" target="_blank">
#                     แฟนปืนช่วยด้วย! ต้ารับ 'ดวลราชัน' เกมใหญ่สุดในอาชี...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/fifa.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556906" target="_blank">
#                     กลับก่อนแข่ง... 'เนย์มาร์' ใส่เสื้อแบทแมนปลุกใจทีม                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556902" target="_blank">
#                     ทีมแรกลีกผู้ดี! 'จิ้งจอก' คาบ้าน 8 นัดติด 'ยิ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556900" target="_blank">
#                     สวมเสื้อไร้สปอนเซอร์! 'มองก้า' ทุบสถิติแข้งเด็กสุด...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556899" target="_blank">
#                     ก่อนกำหนด! 'วิอาน่า' เริ่มงานผอ.ฟุตบอลเรือวันแรก                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/ger.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556898" target="_blank">
#                     เสือเหลืองยวบ 'ชลอตเตอร์เบ็ค' เจ็บเข่าปิดเทอม                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ita.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556892" target="_blank">
#                     อองกีสซ่ายิงไม่พอ! 'นาโปลี' เจ๊าโบโลญญ่า 1-1 ตามงู...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556887" target="_blank">
#                     เมอร์ฟี่ย์ขอเบิ้ล! บาร์นส์ยิงด้วย 'สาลิกา' ซ้ำศพจิ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556883" target="_blank">
#                     เผย...ตำรวจรวบแล้ว แฟนถ่อย 'ตบหน้ากรีลิช' หลังเกมผ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/thailand.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556881" target="_blank">
#                     อินโดไปบอลโลก-เหงียนลุ้นนัดสุดท้าย! ทีมชาติไทย U17 ซ้อมหนีบ๊...                    </a>
# </div>
# <div class="oldnew_p_thead" style="margin:20px 0px 0px 2px;">
# <img alt="" src="/img/web/ss_latest_new_icon_ca.png" style="margin:5px 5px -6px 5px;"/>07/04/25                            </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ita.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556873" target="_blank">
#                     โคลอมเบียสลด 'โบลาโญ่' อดีตแข้งทีมชาติเสียชีวิต                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/ucl.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556869" target="_blank">
#                     กอมปานีมั่นใจ 'พี่เสือเจ็บอื้อ' ยังแกร่งพอชนะงู                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556858" target="_blank">
#                     เอาไหม?...ผีล็อคเป้า 'ดีแลป' ท็อปเป้าหมาย                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/thailand.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556852" target="_blank">
#                     ญี่ปุ่นแชมป์! "ฟุตซอลสาวไทย" เจ๊า "อิหร่าน&amp;qu...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556846" target="_blank">
#                     ซาก้ารักน่อล 'ไม่ทิ้งสโมสร' อยากได้แชมป์กับทีม                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556835" target="_blank">
#                     มาแหวก! ดีนี่ย์ป้อง 'ด่าแม่โฟเด้น' ส่วนหนึ่งฟุตบอล                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556826" target="_blank">
#                     VvD อัพเดตเจรจาสัญญาใหม่ 'มีความคืบหน้า'                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"
    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556609" target="_blank">
#                     'บรูโน่' ซูฮก KDB ยอดแข้ง-หนึ่งในปัจจัยผีไร้แชมป์                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/fifa.jpg" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556608" target="_blank">
#                     ทำอะไรน้อ?! ETH โผล่ชมเกม 'โรม่า-ยูเว่'                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556606" target="_blank">
#                     'เนฟ' ชี้ผีต้องเสริม 5 ตำแหน่งเข้าระบบบอสเจ๋ง                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/esp.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556600" target="_blank">
#                     โซเซียดาดอัดพัลมาส, เคตาเฟ่บุกถล่มบาญาโดลิด..สรุปผล ลาลีกา                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/fra.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556598" target="_blank">
#                     มาร์กเซยชนะ 3-2, สตราส์บูร์กเฉือน 1-0...สรุปผลลีกเอิง                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556597" target="_blank">
#                     โค้ชเจ๋งโต้ 'เนฟ' ปรามาส 'ดาร์บี้เมืองแมนสมาน...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/ita.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556596" target="_blank">
#                     อตา 'คาบ้าน' ลาโอ้ทุบ 1-0 เสี่ยงหลุดท็อป 4...สรุปผ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556592" target="_blank">
#                     เป๊ปยอมรับ 'เรือ' ต้องใช้เวลาคืนฟอร์มเก่ง                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/thailand.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556589" target="_blank">
#                     อดไปบอลโลก! "ช้างศึก U17" สู้เต็มที่นำก่อนพ่าย &amp;qu...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/esp.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556585" target="_blank">
#                     กินกันไม่ลง! 'บิลเบา' จับมือเจ๊า 'เรือดำน้ำ 1...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556584" target="_blank">
#                     สล็อทยัน 'หงส์' ไม่ได้ติดประมาท                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ita.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556583" target="_blank">
#                     โลคายิงไม่พอ! รานิเอรี่แก้เกม 'ม้าลาย' นำก่อนเจ๊าโ...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556579" target="_blank">
#                     'มาเรสก้า' โอดตารางแข่งไม่แฟร์-พอใจ 'สิงห์...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556561" target="_blank">
#                     'อดีตเปา' สับรุ่นน้องเมินแจกแดง 'VvD' ชั...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #99C45F;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556533" target="_blank">
#                     สาลิการอดูอาการ 'อิซาค,ทริปเปียร์' บุกจิ้งจอก...ปร...                    </a>
# </div>
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/eng.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2556501" target="_blank">
#                     ดาร์บี้ส่งท้าย KDB! ผี-เรือ 'ไม่คมทั้งคู่' แบ่งแต้...                    </a>
# </div>
# <div class="oldnew_p_page">
#                         ไปที่หน้า <a href="https://www.soccersuck.com/boards/oldnews/1/" style="color: #000;text-decoration: none;">1</a> |
#                                   <a href="https://www.soccersuck.com/boards/oldnews/2/" style="color: #000;text-decoration: none;">2</a> |
#                                   <a href="https://www.soccersuck.com/boards/oldnews/3/" style="color: #000;text-decoration: none;">3</a>
# </div>
# </div>
# <script type="text/javascript">
#             $(document).ready(function(){
#                 $('.content_right').remove();
#                 $('.adsBottoms').remove();
#             });
#             </script>
# <script src="//anymind360.com/js/4585/ats.js" type="application/javascript"></script>
# </div>
# <div class="content_right">
# <!-- start fix banner -->
# <!-- end fix banner -->
# <!-- adsense display -->
# <div style="
#                     height: 600px;
#                     width: 240px;
#                   ">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- new-position-ads-right-side -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-6459522510239433" data-ad-slot="6528530547" style="display:inline-block;width:240px;height:600px"></ins>
# <script>
#                             (adsbygoogle = window.adsbygoogle || []).push({});
#                         </script>
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# </div>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-LJHELQBHN8"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-LJHELQBHN8');
# </script>
# <div id="footer">
# <div class="contentFooter">
# <a href="https://www.soccersuck.com/">หน้าแรก</a> |
# <a href="https://www.soccersuck.com/boards/oldnews/">ข่าวเก่า</a> |
#    <!-- <a href="http://www.polballss.com/">ทีเด็ด เบน ฟรีคิก</a> |
#     <a href="http://www.guideball.com/">รายงานสดผลบอล</a> | -->
# <!-- <a href="http://live.thaileagueonline.com/main.live">Live Score ไทยลีก</a> | -->
# <a href="https://www.soccersuck.com/boards/topic/1232930/">โปรแกรมถ่ายทอดสด</a> |
#     <!--a href="https://www.soccersuck.com/">ไม่มีกิจห้ามเข้า</a> |  !-->
# <a href="https://www.soccersuck.com/boards/topic/1232930">โปรแกรมบอลล่วงหน้า</a> |
#     <!--a href="#scoreTable">ตารางคะแนน</a> | !-->
# <a href="https://www.soccersuck.com/boards/index">เว็บบอร์ด</a> |
#     <a href="https://www.soccersuck.com/menu/history/">ประวัติ soccersuck</a> |
#     <!--<a href="#">พาร์ทเนอร์</a> |!-->
# <a href="https://www.soccersuck.com/users/contact">ติดต่อโฆษณา</a>
# <div style="font-size: 12px;">Version L-ly 1.0</div>
# <div>
# <div style="float: left; margin: 10px;">
# <a href="https://play.google.com/store/apps/details?id=soccersuck.devtab.com.soccersuck"><img src="/img/web/icon_googleplay.png" width="126"/></a>
# </div>
# <div style="float: left; margin: 10px;">
# <a href="https://itunes.apple.com/bf/app/soccersuck/id1042191005?mt=8"><img src="/img/web/icon_appstore.png" width="126"/></a>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# </div>
# <!-- banner blog-D -->
# <!-- <script src="https://js.rfp.fout.jp/rfp-display.js"></script> -->
# <!-- <script type="text/javascript">RFP.Display.Default.lazyLoading(document.getElementById('rfp-ODg0OjE0NTQ1'))</script> -->
# </body>
# </html>

# %% [markdown]
# #### หา Tag ต่างๆใน Soup

# %%
#หา tag ชื่อ div ที่มี class oldnew_p_tr
#เราสามาร?ถหาโดย id ได้ด้วย แค่เปลี่ยนเป็น id='id_you_are_looking_for'
soup.find('div', class_='oldnew_p_tr')
# Out:
# <div class="oldnew_p_tr" style="background: #C4E29B;">
# <img alt="" src="https://www.soccersuck.com/images/ita.gif" style="margin: 0px 5px -1px 2px;width: 20px;"/> <a href="https://www.soccersuck.com/boards/topic/2557166" target="_blank">
#                     มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้                    </a>
# </div>

# %%
soup.find('div', class_='oldnew_p_tr').find('a')
# Out:
# <a href="https://www.soccersuck.com/boards/topic/2557166" target="_blank">
#                     มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้                    </a>

# %%
#เอา text จาก tag <a>
soup.find('div', class_='oldnew_p_tr').find('a').text.strip(),\
#เอา href จาก tag <a>
soup.find('div', class_='oldnew_p_tr').find('a').get('href')
# Out:
# 'https://www.soccersuck.com/boards/topic/2557166'

# %%
df = pd.DataFrame([
{'headline_abridged': i.text.strip(),
 'url': i.find('a').get('href')} \
 #find() จะหาแค่ tag แรกที่เจอ แต่ find_all() จะหาทุก tag ที่ตรงเงื่อนไข
 for i in soup.find_all('div', class_='oldnew_p_tr')]).head(10)
df
# Out:
#                                                  headline_abridged  \
# 0                   มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้
# 1  ไม่อยากกินบ๊วย! ‘ณัฐกิตติ์’ ยันสู้เต็มที่เพื่อเก็บสามแต้มส่ง...
# 2                    เร่เข้ามา! 'กิตเตนส์' แจ้งขอย้ายออกเสือเหลือง
# 3            แน่จริงนัดมา! สโคลส์เผยเคยโดน 'แข้งผีท้า' ไม่พอใจโ...
# 4                หารายได้! 'ผี' ทัวร์มาเล,ฮ่องกงหลังจบซีซั่น 3 วัน
# 5            ซูเปอร์คอมพ์ยก 'บาร์ซ่าเต็ง' เจ้ายุโรป ปืนเต็ง 3 เ...
# 6  จบรองแชมป์! ฟุตบอลหญิงไทย ต้านไม่ไหวพ่ายเจ้าภาพ จีน 1-5 ศึก ...
# 7            รอดประจำ! แฮ็คเกตต์สงสัย 'VVD' ตีสนิทเปาเลี่ยงใบแด...
# 8                 วินิพอก่อน! อันเช่แต่งตั้ง 'บัปเป้' ตัวยิงจุดโทษ
# 9                          อิบราวาง 'ตาเร่' เต็งหนึ่ง ผอ.กีฬามิลาน
#
#                                                url
# 0  https://www.soccersuck.com/boards/topic/2557166
# 1  https://www.soccersuck.com/boards/topic/2557165
# 2  https://www.soccersuck.com/boards/topic/2557162
# 3  https://www.soccersuck.com/boards/topic/2557156
# 4  https://www.soccersuck.com/boards/topic/2557153
# 5  https://www.soccersuck.com/boards/topic/2557139
# 6  https://www.soccersuck.com/boards/topic/2557131
# 7  https://www.soccersuck.com/boards/topic/2557129
# 8  https://www.soccersuck.com/boards/topic/2557120
# 9  https://www.soccersuck.com/boards/topic/2557048

# %% [markdown]
# #### ดึงข้อมูลจาก url ย่อย

# %%
#จากหน้า list　ข่าว พาดหัวจะแสดงได้ไม่เต็ม
df.loc[0]
# Out:
# headline_abridged     มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้
# url                  https://www.soccersuck.com/boards/topic/2557166
# Name: 0, dtype: object

# %%
#เราสามารถเข้าไปใน url ของข่าวแต่ละข่าวเพื่อไปเอาพาดหัวแบบเต็มและเนื้อข่าวได้
soup = get_soup(df.loc[0,'url'])
soup.find('div', class_='post_head').text.strip(),\
soup.find('div', class_='post_desc').text.strip()
# Out:
# ("มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้",
#  'BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\n\n\nรายงานจาก La Gazzetta dello Sport ระบุว่า เอซี มิลาน เตรียมขายนักเตะดาวดังอย่างน้อย 2 คนในช่วงตลาดซื้อขายซัมเมอร์นี้ เพื่อระดมทุนสำหรับการปฏิวัติทีมครั้งใหญ่ \n\nในรายงานระบุว่า มิลาน มีแผนที่จะปล่อยตัว เตโอ แอร์กน็องเดซ และ  ฟิกาโย่ โทโมริ ออกจากทีมหลังทั้งสองทำผลงานได้ไม่น่าประทับใจนักตลอดฤดูกาล 2024-25\n\nแม้เตโอจะเคยเป็นหนึ่งในนักเตะตัวเด่นของรอสโซเนรีตลอดช่วงที่อยู่กับทีม แต่ฤดูกาลนี้เขากลับทำผลงานต่ำกว่าความคาดหวัง\n\nสัญญาของเขาจะหมดลงในช่วงซัมเมอร์ปี 2026 นั่นหมายความว่าเขาจะเข้าสู่ปีสุดท้ายของสัญญาในซัมเมอร์นี้ และหากไม่มีการต่อสัญญา มิลานก็น่าจะเสี่ยงที่จะเสียเขาไปแบบฟรีๆ \n\nดังนั้น มิลาน จึงเตรียมพิจารณาขายเขาในราคาที่อาจถูกกว่าที่เคยคาดไว้ในช่วงตลาดซัมเมอร์ รายงานระบุว่า มิลานเคยตั้งค่าตัวไว้ราว 50-60 ล้านยูโร ก่อนหน้านี้ แต่ปัจจุบันราคาดังกล่าวอาจลดลง\n\nก่อนหน้านี้ โคโม่ เคยยื่นข้อเสนอประมาณ 40 ล้านยูโรบวกโบนัส เพื่อคว้าตัวแบ็กซ้ายชาวฝรั่งเศสเมื่อเดือนมกราคม และหากนั่นเป็นราคาที่เสนอเมื่อไม่กี่เดือนก่อน รายงานก็ระบุว่ามิลานอาจยอมรับข้อเสนอในระดับ 30 ล้านยูโรบวกโบนัส ในช่วงซัมเมอร์นี้\n\nส่วน โทโมริ ก็มีแนวโน้มจะอำลาถิ่นซาน ซิโร่ เช่นกัน กองหลังชาวอังกฤษอดีตเด็กปั้นเชลซีรายนี้ได้ลงเล่นเพียงนัดเดียวจาก 9 นัดหลังสุดในเซเรีย อา และมีข่าวย้ายทีมต่อเนื่องในช่วงตลาดที่ผ่านมา\n\nโดยมีโอกาสที่เขาจะย้ายกลับไปเล่นในพรีเมียร์ลีก หรือแม้แต่ ยูเวนตุส ที่เคยยื่นข้อเสนอขอยืมตัวพร้อมออปชันซื้อขาดด้วยราคารวมราว 30 ล้านยูโร ในช่วงเดือนมกราคม\n\nโทโมริมีสัญญาถึงปี 2027 ทำให้การขายของเขาไม่เร่งด่วนเท่ากับเตโอ และมิลานก็ไม่มีแรงกดดันให้ต้องลดราคามากนัก\n\nนอกจากเตโอและโทโมริแล้ว La Gazzetta dello Sport ยังรายงานอีกว่า มีนักเตะอีกหลายคนที่อาจถูกขายออกหากมีข้อเสนอที่เหมาะสมเข้ามา ได้แก่ ยูนุส มูซาห์, รูเบน ลอฟตัส-ชีค, ซามูเอล ชุควูเซ่ และ เอแมร์ซอน รอยัล')

# %%
#เขียนฟังชั่นเพื่อเข้าไปดึงข้อมูลจากหน้าข่าว
def get_post_head_desc(url):
    soup = get_soup(url)
    return {'post_head': soup.find('div', class_='post_head').text.strip(),
            'post_desc': soup.find('div', class_='post_desc').text.strip()}

# %%
#วนลูป (map) เพื่อไปดึงพาดหัวแบบเต็มและเนื้อข่าว
df2 = pd.DataFrame(df.url.map(get_post_head_desc).tolist())
df = pd.concat([df,df2],axis=1)
df
# Out:
#                                                  headline_abridged  \
# 0                   มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้
# 1  ไม่อยากกินบ๊วย! ‘ณัฐกิตติ์’ ยันสู้เต็มที่เพื่อเก็บสามแต้มส่ง...
# 2                    เร่เข้ามา! 'กิตเตนส์' แจ้งขอย้ายออกเสือเหลือง
# 3            แน่จริงนัดมา! สโคลส์เผยเคยโดน 'แข้งผีท้า' ไม่พอใจโ...
# 4                หารายได้! 'ผี' ทัวร์มาเล,ฮ่องกงหลังจบซีซั่น 3 วัน
# 5            ซูเปอร์คอมพ์ยก 'บาร์ซ่าเต็ง' เจ้ายุโรป ปืนเต็ง 3 เ...
# 6  จบรองแชมป์! ฟุตบอลหญิงไทย ต้านไม่ไหวพ่ายเจ้าภาพ จีน 1-5 ศึก ...
# 7            รอดประจำ! แฮ็คเกตต์สงสัย 'VVD' ตีสนิทเปาเลี่ยงใบแด...
# 8                 วินิพอก่อน! อันเช่แต่งตั้ง 'บัปเป้' ตัวยิงจุดโทษ
# 9                          อิบราวาง 'ตาเร่' เต็งหนึ่ง ผอ.กีฬามิลาน
#
#                                                url  \
# 0  https://www.soccersuck.com/boards/topic/2557166
# 1  https://www.soccersuck.com/boards/topic/2557165
# 2  https://www.soccersuck.com/boards/topic/2557162
# 3  https://www.soccersuck.com/boards/topic/2557156
# 4  https://www.soccersuck.com/boards/topic/2557153
# 5  https://www.soccersuck.com/boards/topic/2557139
# 6  https://www.soccersuck.com/boards/topic/2557131
# 7  https://www.soccersuck.com/boards/topic/2557129
# 8  https://www.soccersuck.com/boards/topic/2557120
# 9  https://www.soccersuck.com/boards/topic/2557048
#
#                                                                  post_head  \
# 0                           มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้
# 1  ไม่อยากกินบ๊วย! ‘ณัฐกิตติ์’ ยันสู้เต็มที่เพื่อเก็บสามแต้มส่งท้ายจาก จีน
# 2                            เร่เข้ามา! 'กิตเตนส์' แจ้งขอย้ายออกเสือเหลือง
# 3              แน่จริงนัดมา! สโคลส์เผยเคยโดน 'แข้งผีท้า' ไม่พอใจโดนวิจารณ์
# 4                        หารายได้! 'ผี' ทัวร์มาเล,ฮ่องกงหลังจบซีซั่น 3 วัน
# 5              ซูเปอร์คอมพ์ยก 'บาร์ซ่าเต็ง' เจ้ายุโรป ปืนเต็ง 3 เหนือราชัน
# 6          จบรองแชมป์! ฟุตบอลหญิงไทย ต้านไม่ไหวพ่ายเจ้าภาพ จีน 1-5 ศึก CFA
# 7                      รอดประจำ! แฮ็คเกตต์สงสัย 'VVD' ตีสนิทเปาเลี่ยงใบแดง
# 8                         วินิพอก่อน! อันเช่แต่งตั้ง 'บัปเป้' ตัวยิงจุดโทษ
# 9                                  อิบราวาง 'ตาเร่' เต็งหนึ่ง ผอ.กีฬามิลาน
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  post_desc
# 0  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n
BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\nมาร์ก้า รายงาน คาร์โล อันเชล็อตติ กุนซือ เรอัล มาดริด ตัดสินใจถอด วินิซิอุส จูเนียร์ จากหน้าที่ยิงจุดโทษหลีกทางให้ คีเลียน เอ็มบัปเป้ ก่อนทีมแข่ง แชมป์เปี้ยนส์ ลีก บุกเยือน อาร์เซน่อล \n\nช่วงสุดสัปดาห์ วินิซิอุส สังหารจุดโทษไปติดเซฟ จอร์จี้ มามาร์ดาชวิลี่ โกล์คู่แข่งก่อน "ราชัน" แข่ง ลาลีก้า แพ้คาบ้านต่อ บาเลนเซีย 2-1\n\nย้อนไปต้นเดือนมีนาคม วินิซิอุส เพิ่งพลาดจุดโทษในเกม แชมป์เปี้ยนส์ ลีก รอบ 16 ทีมเลกสอง แม้สุดท้าย ม...
# 9  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\nCorriere dello Sport สื่อเมืองมะกะโรนี รายงานว่า ซลาตัน อิบราฮิโมวิช ที่ปรึกษาของเอซี มิลาน เลือก อิ๊กลี่ ตาเร่ อดีตประธานบริหารของลาซิโอ เป็นเต็งหนึ่งตำแหน่ง ผอ.กีฬาคนใหม่\n\nบิ๊กบริหารชาวอัลแบเนี่ยน ที่เคยทำงานภายใต้เคลาดิโอ โลติโต้ในกรุงโรมยาวนาน 15 ปี เป็นตัวเลือกแรกที่ "อิบรา" สนใจระหว่างกระบวนการคัดเลือก ผอ.กีฬา ตั้งแต่ต้น\n\nอยางไรก็ดี "รอสโซ่เนรี่" พยายามมองหาตัวเลือกอื่นด้วย นำมาโดย ฟาบิโอ ปาราติซี่ ที่จะหมดสิท...

# %% [markdown]
# ### Static Web แบบเร็วด้วย Concurrency

# %% [markdown]
# บางครั้งแค่ scape ทีละ url อาจจะไม่ทันใจ เราจึงสามารถ scrape ทีละหลายๆ url "พร้อมๆ" กันได้ด้วย concurrency วิธีมีหลากหลาย แต่เราเลือกใช้วิธีที่แนะนำโดย [Nick Becker, RAPIDS Team at NVIDIA](https://beckernick.github.io/faster-web-scraping-python/)

# %%
import concurrent.futures

# %%
#url ข่าวที่เราต้องการ scrape
urls = df.url.tolist()
urls[:3]
# Out:
# ['https://www.soccersuck.com/boards/topic/2557166',
#  'https://www.soccersuck.com/boards/topic/2557165',
#  'https://www.soccersuck.com/boards/topic/2557162']

# %%
#ฟังชั่นเพื่อเข้าไปดึงข้อมูลจากหน้าข่าวอันเดิม
#เพิ่มเติมคือเราจะบอกให้มันเก็บข้อมูลที่ถูก scrape ไว้ใน list ชื่อ res
def get_post_head_desc_append(url, res):
    soup = get_soup(url)
    res.append({'post_head': soup.find('div', class_='post_head').text.strip(),
            'post_desc': soup.find('div', class_='post_desc').text.strip()})

# %%
#เราใช้ 20 threads คือให้ดึงเต็มที่ 20 url　พร้อมๆกัน
MAX_THREADS = 20

def scrape_multithread(urls, scrape_func):
    threads = min(MAX_THREADS, len(urls))
    with concurrent.futures.ThreadPoolExecutor(max_workers=threads) as executor:
        executor.map(scrape_func, urls)

# %%
#ทำการ scrape แบบ concurrent
from functools import partial

res = []
scrape_multithread(urls, partial(get_post_head_desc_append, res=res))
pd.DataFrame(res)
# Out:
#                                                                  post_head  \
# 0                            เร่เข้ามา! 'กิตเตนส์' แจ้งขอย้ายออกเสือเหลือง
# 1          จบรองแชมป์! ฟุตบอลหญิงไทย ต้านไม่ไหวพ่ายเจ้าภาพ จีน 1-5 ศึก CFA
# 2                        หารายได้! 'ผี' ทัวร์มาเล,ฮ่องกงหลังจบซีซั่น 3 วัน
# 3  ไม่อยากกินบ๊วย! ‘ณัฐกิตติ์’ ยันสู้เต็มที่เพื่อเก็บสามแต้มส่งท้ายจาก จีน
# 4                           มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้
# 5                                  อิบราวาง 'ตาเร่' เต็งหนึ่ง ผอ.กีฬามิลาน
# 6                         วินิพอก่อน! อันเช่แต่งตั้ง 'บัปเป้' ตัวยิงจุดโทษ
# 7              ซูเปอร์คอมพ์ยก 'บาร์ซ่าเต็ง' เจ้ายุโรป ปืนเต็ง 3 เหนือราชัน
# 8                      รอดประจำ! แฮ็คเกตต์สงสัย 'VVD' ตีสนิทเปาเลี่ยงใบแดง
# 9              แน่จริงนัดมา! สโคลส์เผยเคยโดน 'แข้งผีท้า' ไม่พอใจโดนวิจารณ์
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  post_desc
# 0  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\nสกาย เยอรมนี สื่อเบียร์รายงาน เจมี่ กิตเตนส์ ปีกดาวรุ่ง โบรุสเซีย ดอร์ทมุนด์ แจ้งต้นสังกัดขอให้ปล่อยตัวเขาออกช่วงซัมเมอร์นี้\n\nฤดูกาลนี้ แข้งอังกฤษวัย 20 ลงให้ "เสือเหลือง" ไปแล้ว 42 นัดทุกรายการทำ 12 ประตู 5 แอสซิสต์\n\nอย่างไรก็ตาม หลายสัปดาห์หลัง กิตเตนส์ เริ่มหลุดจากตัวจริง โดยครั้งสุดท้ายที่ได้เล่นเต็มเกมใน บุนเดสลีก้า ต้องย้อนไปถึงกลางเดือนมกราคม\n\nนอกจากนี้ ผลงานทีมของ นิโก้ โควิช กำลังรั้งอันดับ 8 เสี่ยงพลาดฟุ...
# 1  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\n\n\nฟุตบอลหญิงไทย ต้านไม่ไหวพ่ายเจ้าภาพ จีน 1-5 “กาญจนธัช พุ่มศรี” ตีไข่แตก จบรองแชมป์ CFA Youngchuan 2025\n\nวันที่ 8 เมษายน 2568 เวลา 18.35 น. ตามเวลาประเทศไทย ณ ศูนย์กีฬาหย่งชวน การแข่งขันฟุตบอล CFA Internation Youngchuan 2025 รองชิงชนะเลิศ ฟุตบอลหญิงทีมชาติไทย ทีมอันดับ 47 ของโลก ลงสนามพบกับ จีน เจ้าภาพ ทีมอันดับ 17 ของโลก \n\nในรอบรองชนะเลิศ ไทย ชนะ แซมเบีย 3-2 ส่วน จีน ชนะ อุซเบกิสถาน 5-0 เกมนี้ ฟูโตชิ อิเคดะ วาง ...
# 2  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n
# %% [markdown]
# จะเห็นว่าใช้เวลาเพียง 2 วินาที เทียบกับการดึงทีละ url ที่ใช้เวลากว่า 15 วินาที

# %%
# %%time
res = []
scrape_multithread(urls, partial(get_post_head_desc_append, res=res))
pd.DataFrame(res)
# Out:
# CPU times: user 446 ms, sys: 21.9 ms, total: 468 ms
# Wall time: 1.31 s
#                                                                  post_head  \
# 0          จบรองแชมป์! ฟุตบอลหญิงไทย ต้านไม่ไหวพ่ายเจ้าภาพ จีน 1-5 ศึก CFA
# 1                                  อิบราวาง 'ตาเร่' เต็งหนึ่ง ผอ.กีฬามิลาน
# 2  ไม่อยากกินบ๊วย! ‘ณัฐกิตติ์’ ยันสู้เต็มที่เพื่อเก็บสามแต้มส่งท้ายจาก จีน
# 3                           มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้
# 4                        หารายได้! 'ผี' ทัวร์มาเล,ฮ่องกงหลังจบซีซั่น 3 วัน
# 5                      รอดประจำ! แฮ็คเกตต์สงสัย 'VVD' ตีสนิทเปาเลี่ยงใบแดง
# 6                         วินิพอก่อน! อันเช่แต่งตั้ง 'บัปเป้' ตัวยิงจุดโทษ
# 7              ซูเปอร์คอมพ์ยก 'บาร์ซ่าเต็ง' เจ้ายุโรป ปืนเต็ง 3 เหนือราชัน
# 8                            เร่เข้ามา! 'กิตเตนส์' แจ้งขอย้ายออกเสือเหลือง
# 9              แน่จริงนัดมา! สโคลส์เผยเคยโดน 'แข้งผีท้า' ไม่พอใจโดนวิจารณ์
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  post_desc
# 0  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\n\n\nฟุตบอลหญิงไทย ต้านไม่ไหวพ่ายเจ้าภาพ จีน 1-5 “กาญจนธัช พุ่มศรี” ตีไข่แตก จบรองแชมป์ CFA Youngchuan 2025\n\nวันที่ 8 เมษายน 2568 เวลา 18.35 น. ตามเวลาประเทศไทย ณ ศูนย์กีฬาหย่งชวน การแข่งขันฟุตบอล CFA Internation Youngchuan 2025 รองชิงชนะเลิศ ฟุตบอลหญิงทีมชาติไทย ทีมอันดับ 47 ของโลก ลงสนามพบกับ จีน เจ้าภาพ ทีมอันดับ 17 ของโลก \n\nในรอบรองชนะเลิศ ไทย ชนะ แซมเบีย 3-2 ส่วน จีน ชนะ อุซเบกิสถาน 5-0 เกมนี้ ฟูโตชิ อิเคดะ วาง ...
# 1  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\nCorriere dello Sport สื่อเมืองมะกะโรนี รายงานว่า ซลาตัน อิบราฮิโมวิช ที่ปรึกษาของเอซี มิลาน เลือก อิ๊กลี่ ตาเร่ อดีตประธานบริหารของลาซิโอ เป็นเต็งหนึ่งตำแหน่ง ผอ.กีฬาคนใหม่\n\nบิ๊กบริหารชาวอัลแบเนี่ยน ที่เคยทำงานภายใต้เคลาดิโอ โลติโต้ในกรุงโรมยาวนาน 15 ปี เป็นตัวเลือกแรกที่ "อิบรา" สนใจระหว่างกระบวนการคัดเลือก ผอ.กีฬา ตั้งแต่ต้น\n\nอยางไรก็ดี "รอสโซ่เนรี่" พยายามมองหาตัวเลือกอื่นด้วย นำมาโดย ฟาบิโอ ปาราติซี่ ที่จะหมดสิท...
# 2  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n
BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\nพอล สโคลส์ เปิดเผยว่า มีนักเตะของแมนเชสเตอร์ ยูไนเต็ด รายหนึ่งไม่พอใจกับคำวิจารณ์ของเขาในฐานะนักวิเคราะห์เกม และถึงขั้นขอนัดเจอกับเขาที่สนามซ้อม\n\n\nพอล สโคลส์ ตำนานแมนเชสเตอร์ ยูไนเต็ดเผยว่า นักเตะชุดปัจจุบันของทีมคนหนึ่งไม่พอใจคำพูดของเขาในฐานะกูรูวิเคราะห์ลูกหนัง และถึงกับอยากนัดพบเพื่อพูดคุยเคลียร์ใจกันที่สนามซ้อม\n\nสโคลส์ เป็นหนึ่งในอดีตนักเตะของยูไนเต็ดหลายคนที่ผันตัวเข้าสู่งานวิเคราะห์เกมหลังจากแขวนสตั๊ด โดยเขา...

# %%
# %%time
def get_post_head_desc(url):
    soup = get_soup(url)
    return {'post_head': soup.find('div', class_='post_head').text.strip(),
            'post_desc': soup.find('div', class_='post_desc').text.strip()}

pd.DataFrame(df.url.map(get_post_head_desc).tolist())
# Out:
# CPU times: user 768 ms, sys: 13 ms, total: 781 ms
# Wall time: 10.3 s
#                                                                  post_head  \
# 0                           มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้
# 1  ไม่อยากกินบ๊วย! ‘ณัฐกิตติ์’ ยันสู้เต็มที่เพื่อเก็บสามแต้มส่งท้ายจาก จีน
# 2                            เร่เข้ามา! 'กิตเตนส์' แจ้งขอย้ายออกเสือเหลือง
# 3              แน่จริงนัดมา! สโคลส์เผยเคยโดน 'แข้งผีท้า' ไม่พอใจโดนวิจารณ์
# 4                        หารายได้! 'ผี' ทัวร์มาเล,ฮ่องกงหลังจบซีซั่น 3 วัน
# 5              ซูเปอร์คอมพ์ยก 'บาร์ซ่าเต็ง' เจ้ายุโรป ปืนเต็ง 3 เหนือราชัน
# 6          จบรองแชมป์! ฟุตบอลหญิงไทย ต้านไม่ไหวพ่ายเจ้าภาพ จีน 1-5 ศึก CFA
# 7                      รอดประจำ! แฮ็คเกตต์สงสัย 'VVD' ตีสนิทเปาเลี่ยงใบแดง
# 8                         วินิพอก่อน! อันเช่แต่งตั้ง 'บัปเป้' ตัวยิงจุดโทษ
# 9                                  อิบราวาง 'ตาเร่' เต็งหนึ่ง ผอ.กีฬามิลาน
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  post_desc
# 0  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\n\n\nรายงานจาก La Gazzetta dello Sport ระบุว่า เอซี มิลาน เตรียมขายนักเตะดาวดังอย่างน้อย 2 คนในช่วงตลาดซื้อขายซัมเมอร์นี้ เพื่อระดมทุนสำหรับการปฏิวัติทีมครั้งใหญ่ \n\nในรายงานระบุว่า มิลาน มีแผนที่จะปล่อยตัว เตโอ แอร์กน็องเดซ และ  ฟิกาโย่ โทโมริ ออกจากทีมหลังทั้งสองทำผลงานได้ไม่น่าประทับใจนักตลอดฤดูกาล 2024-25\n\nแม้เตโอจะเคยเป็นหนึ่งในนักเตะตัวเด่นของรอสโซเนรีตลอดช่วงที่อยู่กับทีม แต่ฤดูกาลนี้เขากลับทำผลงานต่ำกว่าความคา...
# 1  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n
BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\nCorriere dello Sport สื่อเมืองมะกะโรนี รายงานว่า ซลาตัน อิบราฮิโมวิช ที่ปรึกษาของเอซี มิลาน เลือก อิ๊กลี่ ตาเร่ อดีตประธานบริหารของลาซิโอ เป็นเต็งหนึ่งตำแหน่ง ผอ.กีฬาคนใหม่\n\nบิ๊กบริหารชาวอัลแบเนี่ยน ที่เคยทำงานภายใต้เคลาดิโอ โลติโต้ในกรุงโรมยาวนาน 15 ปี เป็นตัวเลือกแรกที่ "อิบรา" สนใจระหว่างกระบวนการคัดเลือก ผอ.กีฬา ตั้งแต่ต้น\n\nอยางไรก็ดี "รอสโซ่เนรี่" พยายามมองหาตัวเลือกอื่นด้วย นำมาโดย ฟาบิโอ ปาราติซี่ ที่จะหมดสิท...

# %%
# %%time
res = []
for url in df.url.tolist():
     res.append(get_post_head_desc(url))
pd.DataFrame(res)
# Out:
# CPU times: user 436 ms, sys: 10.2 ms, total: 446 ms
# Wall time: 9.83 s
#                                                                  post_head  \
# 0                           มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้
# 1  ไม่อยากกินบ๊วย! ‘ณัฐกิตติ์’ ยันสู้เต็มที่เพื่อเก็บสามแต้มส่งท้ายจาก จีน
# 2                            เร่เข้ามา! 'กิตเตนส์' แจ้งขอย้ายออกเสือเหลือง
# 3              แน่จริงนัดมา! สโคลส์เผยเคยโดน 'แข้งผีท้า' ไม่พอใจโดนวิจารณ์
# 4                        หารายได้! 'ผี' ทัวร์มาเล,ฮ่องกงหลังจบซีซั่น 3 วัน
# 5              ซูเปอร์คอมพ์ยก 'บาร์ซ่าเต็ง' เจ้ายุโรป ปืนเต็ง 3 เหนือราชัน
# 6          จบรองแชมป์! ฟุตบอลหญิงไทย ต้านไม่ไหวพ่ายเจ้าภาพ จีน 1-5 ศึก CFA
# 7                      รอดประจำ! แฮ็คเกตต์สงสัย 'VVD' ตีสนิทเปาเลี่ยงใบแดง
# 8                         วินิพอก่อน! อันเช่แต่งตั้ง 'บัปเป้' ตัวยิงจุดโทษ
# 9                                  อิบราวาง 'ตาเร่' เต็งหนึ่ง ผอ.กีฬามิลาน
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  post_desc
# 0  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\n\n\nรายงานจาก La Gazzetta dello Sport ระบุว่า เอซี มิลาน เตรียมขายนักเตะดาวดังอย่างน้อย 2 คนในช่วงตลาดซื้อขายซัมเมอร์นี้ เพื่อระดมทุนสำหรับการปฏิวัติทีมครั้งใหญ่ \n\nในรายงานระบุว่า มิลาน มีแผนที่จะปล่อยตัว เตโอ แอร์กน็องเดซ และ  ฟิกาโย่ โทโมริ ออกจากทีมหลังทั้งสองทำผลงานได้ไม่น่าประทับใจนักตลอดฤดูกาล 2024-25\n\nแม้เตโอจะเคยเป็นหนึ่งในนักเตะตัวเด่นของรอสโซเนรีตลอดช่วงที่อยู่กับทีม แต่ฤดูกาลนี้เขากลับทำผลงานต่ำกว่าความคา...
# 1  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n
# 9  BLOG TOPIC_A\n\t\t\t\t\t\n\n                    ติดต่อรายละเอียดเพิ่มเติมได้ที่ Email:  sale@soccersuck.com \nโปรโมชั่นลดจากเดิม 30% (ไม่รับโฆษณาผิดกฏหมายทุกประเภท) \n\n\n\nCorriere dello Sport สื่อเมืองมะกะโรนี รายงานว่า ซลาตัน อิบราฮิโมวิช ที่ปรึกษาของเอซี มิลาน เลือก อิ๊กลี่ ตาเร่ อดีตประธานบริหารของลาซิโอ เป็นเต็งหนึ่งตำแหน่ง ผอ.กีฬาคนใหม่\n\nบิ๊กบริหารชาวอัลแบเนี่ยน ที่เคยทำงานภายใต้เคลาดิโอ โลติโต้ในกรุงโรมยาวนาน 15 ปี เป็นตัวเลือกแรกที่ "อิบรา" สนใจระหว่างกระบวนการคัดเลือก ผอ.กีฬา ตั้งแต่ต้น\n\nอยางไรก็ดี "รอสโซ่เนรี่" พยายามมองหาตัวเลือกอื่นด้วย นำมาโดย ฟาบิโอ ปาราติซี่ ที่จะหมดสิท...

# %% [markdown]
# ### Dynamic Web

# %% [markdown]
# ในบางกรณี เว็บไซต์จำเป็นต้องให้เราทำกิจกรรมอะไรบางอย่างเพื่อเข้าถึงหน้าที่เราต้องการ scrape เช่น ต้องล็อกอินก่อน, ต้องกดบางปุ่มก่อน เป็นต้น เราเรียกเว็บไซต์ที่มีการเปลี่ยนแปลงจากการทำกิจกรรมอะไรบางอย่างเหล่านี้ว่า Dynamic Web
#
# ในกรณี soccersuck.com สมมุติว่าเราไม่รู้ url ของหน้าต่อไป จำเป็นต้องเขียนโปรแกรมให้กดหน้าต่อไปให้ เราจะใช้ [selenium](https://selenium-python.readthedocs.io) มาช่วยทำกิจกรรมเหล่านี้

# %%
import pandas as pd
import google_colab_selenium as gs

driver = gs.Chrome()
# Out:
#             <div class="spinner-container">
#                 <div class="spinner" id="7774413f-ccbe-4779-888a-47bf18227335-circle"></div>
#                 <div class="spinner-text" id="7774413f-ccbe-4779-888a-47bf18227335-text">Updating and upgrading APT</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="47464ca3-eb2b-4988-8f0b-642a4feaa23b-circle"></div>
#                 <div class="spinner-text" id="47464ca3-eb2b-4988-8f0b-642a4feaa23b-text">Downloading Google Chrome</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
# WARNING:selenium.webdriver.common.selenium_manager:The chromedriver version (90.0.4430.212) detected in PATH at /usr/bin/chromedriver might not be compatible with the detected chrome version (135.0.7049.84); currently, chromedriver 135.0.7049.84 is recommended for chrome 135.*, so it is advised to delete the driver in PATH and retry
#             <div class="spinner-container">
#                 <div class="spinner" id="7722253d-b445-49bb-b83d-d5f6e6609885-circle"></div>
#                 <div class="spinner-text" id="7722253d-b445-49bb-b83d-d5f6e6609885-text">Initializing Chromedriver</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>

# %% [markdown]
# #### Selenium ก็ Scrape Static Web ได้

# %% [markdown]
# ถ้ารันจาก Google Colab อาจจะช้าหน่อย แนะนำให้ติดตั้ง Selenium ในคอมพิวเตอร์ของตัวเองจะเร็วกว่า

# %%
#เข้าไปหน้าข่าวเพื่อเก็บ url เหมือนเดิม
url = f'https://www.soccersuck.com/boards/oldnews'
driver.get(url)
soup = BeautifulSoup(driver.page_source)
driver.close()

df = pd.DataFrame([
{'headline_abridged': i.text.strip(),
 'url': i.find('a').get('href')} for i in soup.find_all('div', class_='oldnew_p_tr')]).head(10)
df
# Out:
#                                    headline_abridged  \
# 0     มิลานเตรียมเลหลังขาย 'เตโอ-โทโมริ' ซัมเมอร์นี้
# 1  ไม่อยากกินบ๊วย! ‘ณัฐกิตติ์’ ยันสู้เต็มที่เพื่อ...
# 2      เร่เข้ามา! 'กิตเตนส์' แจ้งขอย้ายออกเสือเหลือง
# 3  แน่จริงนัดมา! สโคลส์เผยเคยโดน 'แข้งผีท้า' ไม่พ...
# 4  หารายได้! 'ผี' ทัวร์มาเล,ฮ่องกงหลังจบซีซั่น 3 วัน
# 5  ซูเปอร์คอมพ์ยก 'บาร์ซ่าเต็ง' เจ้ายุโรป ปืนเต็ง...
# 6  จบรองแชมป์! ฟุตบอลหญิงไทย ต้านไม่ไหวพ่ายเจ้าภา...
# 7  รอดประจำ! แฮ็คเกตต์สงสัย 'VVD' ตีสนิทเปาเลี่ยง...
# 8   วินิพอก่อน! อันเช่แต่งตั้ง 'บัปเป้' ตัวยิงจุดโทษ
# 9            อิบราวาง 'ตาเร่' เต็งหนึ่ง ผอ.กีฬามิลาน
#
#                                                url
# 0  https://www.soccersuck.com/boards/topic/2557166
# 1  https://www.soccersuck.com/boards/topic/2557165
# 2  https://www.soccersuck.com/boards/topic/2557162
# 3  https://www.soccersuck.com/boards/topic/2557156
# 4  https://www.soccersuck.com/boards/topic/2557153
# 5  https://www.soccersuck.com/boards/topic/2557139
# 6  https://www.soccersuck.com/boards/topic/2557131
# 7  https://www.soccersuck.com/boards/topic/2557129
# 8  https://www.soccersuck.com/boards/topic/2557120
# 9  https://www.soccersuck.com/boards/topic/2557048

# %% [markdown]
# #### Selenium สำหรับ Dynamic Web

# %%
#ฟังชั่นเปลี่ยน soup เป็น dataframe
def get_df(soup):
    return pd.DataFrame([{'headline_abridged': i.text.strip(),
                          'url': i.find('a').get('href')} for i in soup.find_all('div', class_='oldnew_p_tr')])

driver = gs.Chrome()
# Out:
#             <div class="spinner-container">
#                 <div class="spinner" id="29a83c0d-4c83-48fc-980b-564a519917b5-circle"></div>
#                 <div class="spinner-text" id="29a83c0d-4c83-48fc-980b-564a519917b5-text">Initializing Chromedriver</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>

# %%
dfs = []

#เปิดหน้าเว็บตาม url
url = f'https://www.soccersuck.com/boards/oldnews'
driver.get(url)
print(f'Opened {url}')

#เก็บข้อมูล soup และ dataframe จากหน้า 1
soup = BeautifulSoup(driver.page_source)
d = get_df(soup)
d['page'] = '1'
dfs.append(d)
print(f'Saved soup and dataframe from page 1')

#เราจะกดปุ่มหน้า 2 และ 3
for i in ['2','3']:

    #เช็คดูว่าปุ่มหน้าที่จะกด ('2' และ '3') โหลดแล้วหรือยัง
    try:
        element = WebDriverWait(driver, 10).until(
            EC.visibility_of_element_located((By.LINK_TEXT, i))
        )
        print(f'Pagination button {i} found!')
    except:
        print(f'Pagination button {i} NOT found')

    #คลิกไปหน้าถัดไป
    link = driver.find_element(By.LINK_TEXT, i)
    link.click()
    print(f'Clicked pagination button {i}')

    #เก็บข้อมูล soup และ dataframe จากหน้า i
    soup = BeautifulSoup(driver.page_source)
    d = get_df(soup)
    d['page'] = i
    dfs.append(d)
    print(f'Saved soup and dataframe from page {i}')

#ปิดหน้า web
driver.close()
# Out:
# Opened https://www.soccersuck.com/boards/oldnews
# Saved soup and dataframe from page 1
# Pagination button 2 found!
# Clicked pagination button 2
# Saved soup and dataframe from page 2
# Pagination button 3 found!
# Clicked pagination button 3
# Saved soup and dataframe from page 3

# %%
df = pd.concat(dfs).reset_index(drop=True)
df.tail()
# Out:
#                                      headline_abridged  \
# 295  หงส์ไร้ 'พ่อหมี' ไม่ผ่านคอนคัสชั่น, โจนส์แบ็กข...
# 296  ลือหึ่ง...แบร์ต้าพบตัวแทน 'นิโก้' หวังจีบเข้าร...
# 297       'ฮาลันด์' กระหาย ให้คำมั่นจะกลับมาเร็วที่สุด
# 298  ซ้อมครั้งสุดท้าย! ‘อนุรุทธิ์-จเด็จ’ เชื่อหัวใจ...
# 299  พี่เสือต้องลุ้นความพร้อม 'เกร์เรโร่' ไร้เงาซ้อ...
#
#                                                  url page
# 295  https://www.soccersuck.com/boards/topic/2555242    3
# 296  https://www.soccersuck.com/boards/topic/2555237    3
# 297  https://www.soccersuck.com/boards/topic/2555224    3
# 298  https://www.soccersuck.com/boards/topic/2555223    3
# 299  https://www.soccersuck.com/boards/topic/2555222    3

# %% [markdown]
# ## สร้างขึ้นมาเอง

# %% [markdown]
# ### Annotation, Annotation, Annotation

# %% [markdown]
# วิธีที่ตรงไปตรงมาที่สุดคือการเก็บและ label ข้อมูลด้วยมนุษย์ คุณสามารถชวนเพื่อนๆมาทำ หรือแม้แต่จ้างบริษัทมืออาชีพ แน่นอนว่าข้อมูลยิ่งมากยิ่งดี แต่หลายครั้งแค่ 1,000 ตัวอย่างก็พอให้คุณเริ่มทำ ML model ได้แล้ว
#
# ยกตัวอย่างเช่น [@wannaphong](https://github.com/wannaphong) ผู้ก่อตั้ง [PyThaiNLP](https://github.com/PyThaiNLP/pythainlp) ผู้เชี่ยวชาญด้านการสร้างชุดข้อมูลด้วยมือ [@wannaphong](https://github.com/wannaphong) สร้าง
#
# * [thai-named-entity-recognition-data](https://github.com/PyThaiNLP/thai-named-entity-recognition-data/) - ชุดข้อมูล named entity recognition ที่ต่อมารวมกับชุดข้อมูลอีกชุด (ที่ [@wannaphong](https://github.com/wannaphong) ทำการตรวจสอบคุณภาพด้วยมืออีกรอบ) กลายเป็น [ThaiNER](https://github.com/wannaphong/thai-ner) ที่เป็นหนึ่งใน benchmark ที่ใหญ่ที่สุดสำหรับ NER ภาษาไทย ทดลองใช้ได้ที่ [HuggingFace Hub](https://huggingface.co/pythainlp/thainer-corpus-v2-base-model)
#
# * [spelling-check](https://github.com/PyThaiNLP/spelling-check) - ชุดข้อมูลตรวจสอบการสะกดคำภาษาไทยกว่า 1,800 ประโยค; ใช้สำหรับฟังชั่นแก้คำผิดของ [PyThaiNLP](https://github.com/PyThaiNLP/pythainlp)
#
# * [Thai-Lao-Parallel-Corpus](https://github.com/PyThaiNLP/Thai-Lao-Parallel-Corpus) - แปลภาษาไทย-ลาวประมาณ 260 ประโยค
#
# * [thai-sentence](https://github.com/PyThaiNLP/Thai-sentence) - ประโยคภาษาไทยเขียนเองประมาณ 1,000 ประโยค
#
# * [thai-synonym](https://github.com/PyThaiNLP/thai-synonym/) - คำพ้องความหมายประมาณ 100 คำ
#
# ข้อดีของการทำแบบนี้คือคุณจะเข้าใจชุดข้อมูลของคุณได้ดียิ่งขึ้น และยิ่งถ้าคุณเปิดเผยชุดข้อมูลเป็นสาธารณะก็อาจจะมีคนมาช่วยเพิ่มข้อมูลให้คุณอีกด้วย

# %% [markdown]
# ### สร้างข้อมูลเพิ่มด้วย LLM

# %% [markdown]
# ตั้งแต่สิ้นปี 2024 Large Language Model (LLM) ได้พัฒนาไปอย่างก้าวกระโดด ทำให้เราสามารถสร้างข้อมูลทั้ง feature และ outcome ได้จากโมเดลทั้ง open source อย่าง LLaMA หรือ Deepseek หรือจาก API โดยเฉพาะของฟรีเดือนละ 150 USD (ที่ต้องยอมรับที่จะแชร์ข้อมูลให้) อย่าง [xAI/grok](https://docs.x.ai/docs/data-sharing)

# %%
import dspy
from typing import Literal

#เลือกว่าจะใช้ API ไหน
lm = dspy.LM('xai/grok-3-latest', api_key='YOUR_API_KEY',)
dspy.configure(lm=lm)

# %%
#sentiment analysis

class Classify(dspy.Signature):
    """Classify sentiment of a given sentence."""

    sentence: str = dspy.InputField()
    sentiment: Literal['positive', 'negative', 'neutral'] = dspy.OutputField()
    confidence: float = dspy.OutputField()

classify = dspy.Predict(Classify)
classify(sentence="This book was super fun to read, though not the last chapter.")
# Out:
# Prediction(
#     sentiment='positive',
#     confidence=0.85
# )

# %%
#translation

class Translate_Thai_to_Chinese(dspy.Signature):
    """Translate sentence from Thai to Chinese"""

    thai_sentence: str = dspy.InputField()
    chinese_sentence: str = dspy.OutputField()
    confidence: float = dspy.OutputField()

translate = dspy.Predict(Translate_Thai_to_Chinese)
translate(thai_sentence="อั้วเป็งคนจีง มาหากิงอยู่ที่เมืองไทย")
# Out:
# Prediction(
#     chinese_sentence='我是中国人，来到泰国找工作。',
#     confidence=0.85
# )

# %% [markdown]
# ### สร้าง Tabular Data เพิ่มด้วย ML Models

# %% [markdown]
# เริ่มจากถ้าเรามีข้อมูล tabular อยู่บ้าง แต่ต้องการเพิ่มเพื่อให้โมเดลมีประสิทธิภาพขึ้น เราสามารถสร้างชุดข้อมูลเพิ่มด้วยเทคนิค เช่น [CTGAN](https://arxiv.org/abs/1907.00503) เรียกใช้จาก [sdv](https://sdv.dev/SDV/user_guides/single_table/ctgan.html)
#
# เราทดลองใช้ [CTGAN](https://arxiv.org/abs/1907.00503) สร้างชุดข้อมูลเพิ่มสำหรับโมเดล [xgboost](https://xgboost.readthedocs.io/en/stable/) ในบทที่ 1

# %% [markdown]
# จำแนกการตอบสนองของลูกค้ากับแคมเปญที่บริษัทจัดด้วยชุดข้อมูล [Retail Transaction Data](https://www.kaggle.com/regivm/retailtransactiondata) จัดทำโดย []() ดูตัวอย่างการวิเคราะห์เต็มๆได้ที่ [Campaign Response Model - Example.ipynb](https://colab.research.google.com/drive/1eTVlSYcwUYkYDW6sPTY8XVO1QMhr-DNT?usp=sharing)

# %%
#download data
# !wget https://github.com/ai-builders/curriculum/raw/main/data/Retail_Data_Transactions.csv
# !wget https://github.com/ai-builders/curriculum/raw/main/data/Retail_Data_Response.csv
# Out:
# --2025-04-10 00:36:17--  https://github.com/ai-builders/curriculum/raw/main/data/Retail_Data_Transactions.csv
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ai-builders/curriculum/main/data/Retail_Data_Transactions.csv [following]
# --2025-04-10 00:36:18--  https://raw.githubusercontent.com/ai-builders/curriculum/main/data/Retail_Data_Transactions.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2633502 (2.5M) [text/plain]
# Saving to: ‘Retail_Data_Transactions.csv’
#
# Retail_Data_Transac 100%[===================>]   2.51M  --.-KB/s    in 0.05s
#
# 2025-04-10 00:36:18 (48.3 MB/s) - ‘Retail_Data_Transactions.csv’ saved [2633502/2633502]
#
# --2025-04-10 00:36:18--  https://github.com/ai-builders/curriculum/raw/main/data/Retail_Data_Response.csv
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ai-builders/curriculum/main/data/Retail_Data_Response.csv [following]
# --2025-04-10 00:36:19--  https://raw.githubusercontent.com/ai-builders/curriculum/main/data/Retail_Data_Response.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68862 (67K) [text/plain]
# Saving to: ‘Retail_Data_Response.csv’
#
# Retail_Data_Respons 100%[===================>]  67.25K  --.-KB/s    in 0.02s
#
# 2025-04-10 00:36:19 (4.09 MB/s) - ‘Retail_Data_Response.csv’ saved [68862/68862]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score

#จัดการข้อมูลให้อยู่ในรูปแบบ (X, y)
df_response = pd.read_csv('Retail_Data_Response.csv')
df_trans = pd.read_csv('Retail_Data_Transactions.csv', parse_dates=['trans_date'])

campaign_date = datetime(2015,3,17)
df_trans['age'] = (campaign_date - df_trans.trans_date).dt.days

df = df_trans.groupby('customer_id').agg(
    recency=('age', 'min'),
    frequency=('customer_id', 'count'),
    monetary=('tran_amount', 'sum'),
    tenure=('age', 'max'),
    length_of_stay=('age', lambda x: x.max() - x.min())
)
df['ticket_size'] = df.monetary / df.frequency
df['std_ticket_size'] = df_trans.groupby('customer_id').tran_amount.std()
df['cv_ticket_size'] = df.std_ticket_size / df.ticket_size

# the number of months visited
active_months = df_trans.groupby(['customer_id', pd.Grouper(key='trans_date',freq='M')]).size().reset_index()
active_months = active_months.groupby('customer_id').trans_date.nunique()
df['active_months'] = active_months
df['avg_spend_m'] = df.monetary / df.active_months
df['avg_visit_m'] = df.frequency / df.active_months
# done with active_months, then drop it
df = df.drop(columns='active_months')
df['avg_tte'] = df.length_of_stay / (df.frequency - 1)

#all data
all_data = df_response.join(df, how='inner', on='customer_id').set_index('customer_id')

#split ข้อมูลเป็น train, validation และ test
random_state = 1024
test_size = 0.2
val_size = 0.2

X = all_data.drop(columns='response')
y = all_data.response

X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=test_size,
                                                            stratify=y, random_state=random_state)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=val_size/(1-test_size),
                                                  stratify=y_train_val, random_state=random_state)

train_data = X_train.join(y_train)
val_data = X_val.join(y_val)
test_data = X_test.join(y_test)

train_data.shape, val_data.shape, test_data.shape
# Out:
# <ipython-input-29-9a58f00eaf2a>:13: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_trans = pd.read_csv('Retail_Data_Transactions.csv', parse_dates=['trans_date'])
# <ipython-input-29-9a58f00eaf2a>:30: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   active_months = df_trans.groupby(['customer_id', pd.Grouper(key='trans_date',freq='M')]).size().reset_index()
# ((4130, 12), (1377, 12), (1377, 12))

# %% [markdown]
# เราสร้างชุดข้อมูลเพิ่มจาก `train data` ด้วย CTGAN (ระวังอย่าสร้างจาก validation หรือ test sets ไม่งั้นจะเปิด data leakage ("โกงข้อสอบ")

# %%
from ctgan import CTGAN

#สร้างโมเดล CTGAN เพื่อเรียนรู้จากข้อมูล
model = CTGAN()
model.fit(train_data)

#สร้างชุดข้อมูลใหม่มา 4000 ตัวอย่าง (เดิม training set มี 4,130 ตัวอย่าง)
new_train_data = model.sample(4000)
new_train_data.tail()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py:823: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:180.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#       recency  frequency  monetary  tenure  length_of_stay  ticket_size  \
# 3995       99         15      1005    1267            1182    36.614005
# 3996      165         12      1113    1394            1175    74.172513
# 3997        7          9       507    1284            1098    34.371004
# 3998        7         25      1030    1405            1350    63.412568
# 3999       -2         29      1749    1363            1311    74.122562
#
#       std_ticket_size  cv_ticket_size  avg_spend_m  avg_visit_m     avg_tte  \
# 3995        23.126709        0.493108    50.184188     1.280860   75.676774
# 3996        23.045127        0.273257    90.350442     1.142732   52.168265
# 3997        18.655344        0.603348    59.483124     1.063922  105.455004
# 3998        21.354694        0.260896   113.418618     1.337216   52.029523
# 3999        19.545781        0.340814   100.378064     1.462202   76.025538
#
#       response
# 3995         0
# 3996         0
# 3997         0
# 3998         0
# 3999         0

# %%
from sdv.metadata import Metadata

metadata = Metadata.detect_from_dataframes(
    data={
        'train_data': train_data,
    })
metadata
# Out:
# {
#     "tables": {
#         "train_data": {
#             "columns": {
#                 "recency": {
#                     "sdtype": "numerical"
#                 },
#                 "frequency": {
#                     "sdtype": "numerical"
#                 },
#                 "monetary": {
#                     "sdtype": "numerical"
#                 },
#                 "tenure": {
#                     "sdtype": "numerical"
#                 },
#                 "length_of_stay": {
#                     "sdtype": "numerical"
#                 },
#                 "ticket_size": {
#                     "sdtype": "numerical"
#                 },
#                 "std_ticket_size": {
#                     "sdtype": "numerical"
#                 },
#                 "cv_ticket_size": {
#                     "sdtype": "numerical"
#                 },
#                 "avg_spend_m": {
#                     "sdtype": "numerical"
#                 },
#                 "avg_visit_m": {
#                     "sdtype": "numerical"
#                 },
#                 "avg_tte": {
#                     "sdtype": "numerical"
#                 },
#                 "response": {
#                     "sdtype": "categorical"
#                 }
#             }
#         }
#     },
#     "relationships": [],
#     "METADATA_SPEC_VERSION": "V1"
# }

# %%
#ประเมินว่าสร้างข้อมูลปลอมได้ดีแค่ไหน; ค่ายิ่งสูงยิ่งดี
from sdv.evaluation.single_table import evaluate_quality

quality_report = evaluate_quality(
    train_data,
    new_train_data,
    metadata)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 12/12 [00:01<00:00,  7.66it/s]|
# Column Shapes Score: 90.25%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 66/66 [00:01<00:00, 42.77it/s]|
# Column Pair Trends Score: 89.53%
#
# Overall Score (Average): 89.89%

# %%
#สร้าง X_train_new และ y_train_new ด้วยการเพิ่มข้อมูลปลอมเข้าไป
X_train_new = pd.concat([X_train,new_train_data.drop(columns='response')])
y_train_new = pd.concat([y_train,new_train_data.response])

# %%
#สร้างโมเดลต้นไม้ด้วย xgboost (gradient boosted trees)
import xgboost as xgb

#เทรนด้วยข้อมูลจริง
xgb_params = {'objective': 'binary:logistic',
              'random_state': 1024,
              'eval_metric': 'auc',
              'early_stopping_rounds': 10,
              'scale_pos_weight' : (len(y_train) - sum(y_train)) / sum(y_train),
              'max_depth': 3,
              'booster':'gbtree',
              }

model = xgb.XGBClassifier(**xgb_params)
model = model.fit(X_train,
                  y_train,
                  eval_set=[(X_val,y_val)],
                  verbose=False)

#เทรนด้วยข้อมูลจริง + ข้อมูลปลอม
xgb_params_new = {'objective': 'binary:logistic',
              'random_state': 1024,
              'eval_metric': 'auc',
              'early_stopping_rounds': 10,
              'scale_pos_weight' : (len(y_train_new) - sum(y_train_new)) / sum(y_train_new),
              'max_depth': 3,
              'booster':'gbtree',
              }

model_new = xgb.XGBClassifier(**xgb_params_new)
model_new = model_new.fit(X_train_new,
                  y_train_new,
                  eval_set=[(X_val,y_val)],
                  verbose=False)

# %% [markdown]
# จะเห็นได้ว่าเมื่อเพิ่มข้อมูลปลอมเข้าไปแล้ว micro-averaged F1 และ accuracy ดีขึ้น แต่ AUC แย่ลง เพราะฉะนั้นการที่เราจะเพิ่มข้อมูลปลอมเข้าไปเทรนจำเป็นต้องคำนึงถึงว่าเราต้องการวัดผลของโมเดลด้วย metric ใด

# %%
#รายงานผลโมเดลเทรนบนข้อมูลจริง
print(f'AUC: {roc_auc_score(y_test, model.predict_proba(X_test)[:,1])}')
print(classification_report(y_test,model.predict_proba(X_test)[:,1].round()))
# Out:
# AUC: 0.7742061717352415
#               precision    recall  f1-score   support
#
#            0       0.97      0.63      0.77      1248
#            1       0.18      0.78      0.29       129
#
#     accuracy                           0.65      1377
#    macro avg       0.57      0.71      0.53      1377
# weighted avg       0.89      0.65      0.72      1377

# %%
#รายงานผลโมเดลเทรนบนข้อมูลจริง+ข้อมูลปลอม
print(f'AUC: {roc_auc_score(y_test, model_new.predict_proba(X_test)[:,1])}')
print(classification_report(y_test,model_new.predict_proba(X_test)[:,1].round()))
# Out:
# AUC: 0.7671499204929437
#               precision    recall  f1-score   support
#
#            0       0.97      0.58      0.73      1248
#            1       0.17      0.84      0.28       129
#
#     accuracy                           0.60      1377
#    macro avg       0.57      0.71      0.50      1377
# weighted avg       0.90      0.60      0.68      1377

# %% [markdown]
# ### สร้าง Texts จาก ML Models

# %% [markdown]
# สำหรับโมเดล NLP นั้นโชคดีที่ในอินเตอร์เน็ตมีข้อความมากมายให้นักวิจัยสามารถเทรนโมเดลขนาดใหญ่ได้ฟรี เราจึงมีโมเดลที่สามารถสร้างข้อความในแบบที่เราต้องการให้เลือกใช้ได้อย่างหลากหลายใน [HuggingFace Hub](https://huggingface.co/models)
#
# เทคนิคการสร้างข้อความปลอมเพื่อมาเทรนโมเดลนี้เคยถูกใช้สำหรับเทรน[โมเดลแปลภาษาไทย-อังกฤษของ VISTEC](https://airesearch.in.th/releases/machine-translation-models/) ที่สามารถทำผลงานได้ดีที่สุด ณ วันตีพิมพ์ (หาอ่านงานวิจัยได้ที่ [scb-mt-en-th-2020: A Large English-Thai Parallel Corpus](https://arxiv.org/abs/2007.03541)) โดยเราใช้โมเดล [CTRL](https://github.com/salesforce/ctrl) สร้างข้อความรีวิวสินค้าระหว่าง 1-5 ดาวเป็นภาษาอังกฤษออกมาเพื่อให้นักแปลนำไปแปลเพื่อสร้างคู่ประโยคสำหรับเทรนโมเดลอีกที (ดูรายละเอียดได้ที่ [vistec-ai/fake_reviews](https://github.com/vistec-AI/fake_reviews))
#
# แน่นอนว่าทุกวันนี้มีโมเดลที่สามารถสร้างข้อความได้แทบทุกรูปแบบ เราจะยกตัวอย่างโมเดล [GPT](https://arxiv.org/abs/2005.14165) สำหรับการสร้างรีวิวสินค้า 1 ดาวและ 5 ดาว

# %%
from transformers import pipeline
import pprint

#โหลด generator สำหรับรีวิว 1 ดาว
generator1 = pipeline(
    "text-generation",
    model="ehdwns1516/gpt2_review_star1",
    framework="pt",
)

# %%
context = '<|endoftext|>' #โมเดลต้องการ token พิเศษนี้นำหน้าเพื่อสร้างข้อความ
pprint.pprint([i['generated_text'] for i in generator1(context,
                                                      max_length = 60, #ให้แต่ละประโยคมีความยาว 60 token
                                                      num_return_sequences=3 #สร้างมา 3 ประโยค
                                                       )])
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py:1201: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ['<|endoftext|>I have two of these and neither side worked. My phone stopped '
#  'charging after the second month in use.I’ve had the new one 3 days before '
#  'and the cable was stopped. Had to charge my cell phone and cable. The new '
#  'one is the same.The lid isn’',
#  '<|endoftext|>This item is not for the original purchase, the seller is '
#  'contacting customer support to cancel that order.This set looks great and '
#  'seems like a good size to pack a few snacks in. But I’m very frustrated as '
#  'of this moment with the purchase. The screen protector is the only option',
#  '<|endoftext|>The item that was sent was a rip. I wish I had read all the '
#  'reviews before purchasing the item. The clip would also be fine for a short '
#  'clip. The clip itself is solid but the clip has already snapped on the end '
#  "for the item to fit properly. I've had it about"]

# %%
#โหลด generator สำหรับรีวิว 1 ดาว
generator5 = pipeline(
    "text-generation",
    model="ehdwns1516/gpt2_review_star5",
    framework="pt",
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/510M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/638 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/387 [00:00<?, ?B/s]

# %%
context = '<|endoftext|>' #โมเดลต้องการ token พิเศษนี้นำหน้าเพื่อสร้างข้อความ
pprint.pprint([i['generated_text'] for i in generator5(context,
                                                      max_length = 60, #ให้แต่ละประโยคมีความยาว 60 token
                                                      num_return_sequences=3 #สร้างมา 3 ประโยค
                                                       )])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ['<|endoftext|>I bought this pillow case for my little grandson after he said '
#  'he liked it. It fits exactly what I was looking for and they have not '
#  'complained at all about it. I am so happy for the performance!Nice and '
#  "strong but doesn't move well. Looks good in our trailer.Worked",
#  '<|endoftext|>I bought it for my daughter’s birthday. She was excited when '
#  'her friends opened the box and found a sample of chocolate cake. The cake '
#  'came quickly and the packaging is great.This is a great book for the '
#  'beginner. I got the book to review the products because I have a',
#  '<|endoftext|>Bought this as an alternative to a brand name brand replacement '
#  'because I wanted to try something different. This one does exactly what I '
#  'was looking for and actually works! The magnet keeps the product on my hand '
#  "as I walk. I don't have to worry about my phone going off or losing its"]

# %% [markdown]
# ### สร้าง Images จาก ML Models
#
# เช่นเดียวกับข้อมูลข้อความ โมเดลขนาดใหญ่ที่ถูกเทรนด้วยรูปภาพมหาศาลก็สามารถสร้างรูปภาพปลอมเพื่อให้คุณไปเทรนโมเดลได้เช่นกัน เช่น [DALL-E Mini](https://github.com/borisdayma/dalle-mini) ที่เป็นโมเดล open source สร้างเลียนแบบโมเดล [DALL-E](https://openai.com/blog/dall-e/) ของ [OpenAI](https://openai.com/)
#
# วิธีการสร้างรูปภาพค่อนข้างซับซ้อนและกินเวลานาน แนะนำให้ไปลองเล่นกันที่ [demo](https://huggingface.co/spaces/flax-community/dalle-mini) หรือดูรายละเอียดที่ [github repository](https://github.com/borisdayma/dalle-mini)
#
# <img src=https://github.com/ai-builders/curriculum/raw/main/images/dalle_e_toast.png width="700px">

# %% [markdown]
# อีกตัวอย่างใกล้ตัวคือการใช้ Generative Adversarial Networks (GAN) เรียนรู้จากรูปที่เรามีอยู่เพื่อสร้างตัวอย่างเพิ่มขึ้น เช่น การสร้าง Anime faces จากรูปที่มีอยู่โดย [@konkuad](https://github.com/konkuad) ใน [konkuad/GANime](https://github.com/konkuad/GANime)

# %%
# !rm -r GANime
# !git clone https://github.com/konkuad/GANime
# !cd GANime; pip install .

# %%
import torch
from GANime.gan import GAN

#initialize new model with random weights
seed_size=128
new_gan_model = GAN(seed_size)
#load model trained for 100 epochs
new_gan_model.gen.load_state_dict(torch.load('GANime/example_models/gen.pt'))
new_gan_model.dis.load_state_dict(torch.load('GANime/example_models/dis.pt'))
#infer generation
generated_images = new_gan_model.generate(num_rows=8,
               num_cols=8,
               plot=True,
               device='cpu',
               return_noise=False
              )

# %% [markdown]
# # Checkpoint ท้ายบท

# %% [markdown]
# ## คำถามชวนคิดเกี่ยวกับบทเรียน

# %% [markdown]
# 1. คุณคิดว่าปัญหาที่คุณกำลังจะแก้ด้วย ML นั้นปริมาณและคุณภาพของข้อมูลที่ใช้เทรน (Data-Centric AI) หรือประสิทธิภาพของโมเดล (Model-Centric AI) สำคัญกว่ากัน เพราะอะไร
#
# 2. คุณคิดว่า open data และ open source มีข้อดี-ข้อเสียอย่างไรต่อ 1) ผู้สร้างผลงาน 2) ผู้นำผลงานไปใช้ 3) ชุมชน 4) สังคมโดยรวม
#
# 3. คุณคิดว่าการใช้ข้อมูลสาธารณะจากเว็บไซต์ต่างๆมาเทรนโมเดลมีข้อควรระวังอะไรบ้าง
#
# 4. การเทรนโมเดลด้วยข้อมูลที่สร้างขึ้นมาจากอีกโมเดลหนึ่ง ("ข้อมูลปลอม") นั้นมีข้อดี-ข้อเสียอย่างไรบ้าง

# %% [markdown]
# ## สิ่งที่ควรเตรียมพร้อมสำหรับทำโครงงาน

# %% [markdown]
# ### ☑️ ทบทวนระบบการให้คะแนนโครงงานให้เรียบร้อย
#
# AI Builders จะออกใบประกาศนียบัตรจบการศึกษาให้กับผู้เข้าร่วมโครงการที่ส่งโครงงานได้คะแนนอย่างน้อย 70 จาก 100 คะแนนตามเกณฑ์ต่อไปนี้เท่านั้น
#
# 1. problem statement; เหตุผลในการแก้ปัญหาเชิงธุรกิจ/ชีวิตประจำวันด้วย machine learning - 15 คะแนน
# 2. metrics and baselines; การให้เหตุผลเชื่อมโยงการแก้ปัญหากับตัวชี้วัดที่เลือก / การวัดผลเทียบกับวิธีแก้ปัญหาในปัจจุบัน - 15 คะแนน
#
# **วันนี้เราจะคิดถึง 2 ข้อนี้เป็นพิเศษ**
#
# **3. data collection and cleaning; การเก็บและทำความสะอาดข้อมูล - 15 คะแนน**
#
#
# **4. exploratory data analysis; การทำความเข้าใจข้อมูล - 20 คะแนน**
#
#
# 5. modeling, validation and error analysis; การทำโมเดล, ทดสอบโมเดล และวิเคราะห์ข้อผิดพลาดของโมเดล - 20 คะแนน
# 6. deployment; การนำโมเดลไปใช้แก้ปัญหาจริง - 15 คะแนน

# %% [markdown]
# ### ☑️ หาข้อมูลมาจากไหนดี
#
# จากแหล่งข้อมูลทั้งหมดที่กล่าวมาในบทเรียนนี้ คุณคิดว่าจะหาชุดข้อมูลจากไหนมาเทรนโมเดล

# %% [markdown]
# ### ☑️ คุณภาพของข้อมูล Labels และ Inputs
#
# ข้อมูลที่คุณได้มาจากอินเตอร์เน็ตไม่ว่าจะดาวน์โหลดชุดข้อมูลของคนอื่น, scrape เว็บไซต์, ใช้โมเดลคนอื่นสร้างขึ้นมา คุณต้องทำให้แน่ใจว่าคุณภาพมันพร้อมใช้งานทั้ง Labels และ Inputs เช่น ถ้าอยากทำโมเดลแปลภาษาไทย-จีนก็ต้องทำให้แน่ใจว่าคู่ประโยคที่เราหามามันแปลตรงกันจริงๆ เป็นต้น

# %% [markdown]
# ### ☑️ Train-validation-test Splits สมเหตุสมผลไหม
#
# ใช้สามัญสำนึกและตรรกะในการแบ่งข้อมูลเป็น train, validation, test sets ทำให้มั่นใจว่าไม่มีตัวอย่างเดียวกันหลุดไปใน set อื่น เช่น
#
# * ในการทำ face recognition ไม่ควรมีรูปคนๆเดียวกันในมากกว่า 1 set
#
# * หากทำ time series forecasting เรียงข้อมูลจากเก่าสุดไปใหม่สุดใน `train`, `validation` และ `test` เพื่อไม่ให้โมเดลเห็นข้อมูลจากอนาคต
#
# * หากทำ product recommendation ไม่ควรมีข้อมูลของลูกค้าคนเดียวกันในมากกว่า 1 set เพราะจะทำให้เราเดาว่าเขาเป็นลูกค้าประเภทไหนได้ด้วยข้อมูลที่ไม่ควรเห็น ฯลฯ
#
# ทั้งนี้ขึ้นอยู่กับวิจารณญาณของผู้สร้างโมเดล เรียนรู้เพิ่มเติมเกี่ยวกับการ split ข้อมูลได้จาก เรียนรู้เพิ่มเติมเกี่ยวกับ metric ได้จาก [DS&AI Academy](https://www.youtube.com/playlist?list=PL1kutgc5YvC841TmatsLuj4sDKkwj95Dz)
